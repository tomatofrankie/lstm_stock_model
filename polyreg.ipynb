# %%
from pandas_datareader.data import DataReader
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from datetime import datetime

# Get the stock quote
user_input = input('Input the ticker:')
df = DataReader(user_input, data_source='yahoo', start='2018-01-01', end=datetime.now())
# Create a new dataframe with only the 'Close column 
data = df.filter(['Close'])
print(data)

# Convert the dataframe to a numpy array
dataset = data.values
date = data.index

#print(len(date))
# Out:
# Input the ticker:nvda
#                  Close
# Date
# 2018-01-02   49.837502
# 2018-01-03   53.117500
# 2018-01-04   53.397499
# 2018-01-05   53.849998
# 2018-01-08   55.500000
# ...                ...
# 2022-04-25  199.020004
# 2022-04-26  187.880005
# 2022-04-27  184.149994
# 2022-04-28  197.820007
# 2022-04-29  185.470001
#
# [1090 rows x 1 columns]

# %%
date = np.linspace(1,len(date),len(date))
dataset = dataset.flatten()
mymodel = np.poly1d(np.polyfit(date, dataset, 3))
plt.figure(figsize=(12, 10), dpi=80)
plt.scatter(date, dataset)
plt.plot(date, mymodel(date))
plt.show()

# %%
from pandas_datareader.data import DataReader
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from datetime import datetime

# Get the stock quote

while True:
    user_input = input('Input the ticker:')
    if user_input == 'quit()':
        break
    df = DataReader(user_input, data_source='yahoo', start='2018-01-01', end=datetime.now())
    # Create a new dataframe with only the 'Close column 
    data = df.filter(['Close'])
    print(data)

    # Convert the dataframe to a numpy array
    dataset = data.values
    date = data.index

    date = np.linspace(1,len(date),len(date))
    dataset = dataset.flatten()
    mymodel = np.poly1d(np.polyfit(date, dataset, 3))
    plt.figure(figsize=(12, 10), dpi=80)
    plt.scatter(date, dataset)
    plt.plot(date, mymodel(date))
    plt.show()
# Out:
# Input the ticker:nvda
#                  Close
# Date
# 2018-01-02   49.837502
# 2018-01-03   53.117500
# 2018-01-04   53.397499
# 2018-01-05   53.849998
# 2018-01-08   55.500000
# ...                ...
# 2022-04-25  199.020004
# 2022-04-26  187.880005
# 2022-04-27  184.149994
# 2022-04-28  197.820007
# 2022-04-29  185.470001
#
# [1090 rows x 1 columns]
