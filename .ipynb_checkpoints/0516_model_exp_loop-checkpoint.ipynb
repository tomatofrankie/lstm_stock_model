# %%
from pandas_datareader.data import DataReader
import numpy as np
import plotly.graph_objs as go
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import yfinance as yf
from stockstats import StockDataFrame
from keras.preprocessing.sequence import TimeseriesGenerator

user_input = input('Input the ticker:')
df = DataReader(user_input, data_source='yahoo', start='2018-01-01', end=datetime.now())
data = df.filter(['Close'])
print(data)

dataset = data.values
date = data.index

date_number = np.linspace(1,len(date),len(date))
dataset = dataset.flatten()
mymodel = np.poly1d(np.polyfit(date_number, dataset, 3))
plt.figure(figsize=(12, 10), dpi=80)
plt.plot(date, dataset)
plt.plot(date, mymodel(date_number))
plt.show()
# Out:
# Input the ticker:aapl
#                  Close
# Date
# 2018-01-02   43.064999
# 2018-01-03   43.057499
# 2018-01-04   43.257500
# 2018-01-05   43.750000
# 2018-01-08   43.587502
# ...                ...
# 2022-05-16  145.539993
# 2022-05-17  149.240005
# 2022-05-18  140.820007
# 2022-05-19  137.350006
# 2022-05-20  137.589996
#
# [1105 rows x 1 columns]

# %%
stock = StockDataFrame.retype(df)
#stock.init_all()

# print(stock)
rsi = stock['rsi']
kdj = stock['kdjk']
macd = stock['macd']
boll = stock['boll']
ma = stock['tema']

rsi = rsi[2:]
kdj = kdj[2:]
macd = macd[2:]
boll = boll[2:]
ma = ma[2:]

close_data_pd = pd.concat([data[2:],rsi],axis=1)
#close_data_pd = close_data_pd.drop(close_data_pd.index[0:6])

close_data_pd.head
# Out:
# <bound method NDFrame.head of                  Close        rsi
# Date
# 2018-01-04   43.257500  96.635175
# 2018-01-05   43.750000  99.055536
# 2018-01-08   43.587502  78.891578
# 2018-01-09   43.582500  78.362883
# 2018-01-10   43.572498  77.247879
# ...                ...        ...
# 2022-05-16  145.539993  36.688188
# 2022-05-17  149.240005  41.366365
# 2022-05-18  140.820007  35.024001
# 2022-05-19  137.350006  32.792580
# 2022-05-20  137.589996  33.109993
#
# [1103 rows x 2 columns]>

# %%
mae_list = []

for _ in range(5):
    close_data = close_data_pd.to_numpy()

    split_percent = 0.9
    look_back = 10
    split = int(split_percent * len(close_data))

    close_train = close_data[:split]
    close_test = close_data[split:]

    date_train = date[:split]
    date_test1 = date[split+2:]
    date_test2 = date_test1.delete(slice(0,look_back))

    train_generator = TimeseriesGenerator(close_train, close_train, length=look_back, batch_size=20)
    test_generator = TimeseriesGenerator(close_test, close_test, length=look_back, batch_size=1)


    from keras.models import Sequential
    from keras.layers import LSTM, Dense, Dropout

    model = Sequential()

    model.add(
        LSTM(50,
             activation='relu',
             #return_sequences=True,
             input_shape=(look_back,close_train.shape[1]))
    )
    model.add(Dropout(0.2))

    # model.add(LSTM(128, return_sequences=True, input_shape= (date_train.shape[0], 1)))
    # model.add(LSTM(64, return_sequences=False))
    # model.add(Dense(25))

    model.add(Dense(units=1))
    model.compile(optimizer='adam', loss='mse')

    num_epochs = 25
    model.fit(train_generator, epochs=num_epochs, verbose=1)

    rsi_array = rsi.to_numpy()
    kdj_array = kdj.to_numpy()
    macd_array = macd.to_numpy()
    boll_array = boll.to_numpy()
    ma_array = ma.to_numpy()

    prediction = model.predict(test_generator) + rsi.mean()
    train_price = np.delete(close_train,slice(1,close_train.shape[1]),1)
    test_price = np.delete(close_test,slice(1,close_train.shape[1]),1)
    print('\nHead of validation results:\n',prediction[:5])

    train = train_price.reshape((-1))
    test = test_price.reshape((-1))
    prediction = prediction.reshape((-1))

    trace1 = go.Scatter(
        x=date_train,
        y=train,
        mode='lines',
        name='Data'
    )
    trace2 = go.Scatter(
        x=date_test2,
        y=prediction,
        mode='lines',
        name='Prediction'
    )
    trace3 = go.Scatter(
        x=date_test1,
        y=test,
        mode='lines',
        name='Ground Truth'
    )
    layout = go.Layout(
        title="Stock",
        xaxis={'title': "Date"},
        yaxis={'title': "Close"}
    )

    #close_data = close_data.reshape((-1))
    fig = go.Figure(data=[trace1, trace2, trace3], layout=layout)
    fig.show()

    def predict(num_prediction, model):
        prediction_list = close_test[-2*look_back:]

        for i in range(num_prediction):
            x = prediction_list[-look_back:]
    #         x_list = x.tolist()
    #         x_series = pd.Series(x_list)
    #         print(x_series)
    #         x_series = np.asarray(x_series).astype('float32')
    #         print(x_series)

            #x = x.reshape((1, look_back, 4))
            x = TimeseriesGenerator(x,x, length=look_back-1, batch_size=1)
            out = [float(model.predict(x)),0]
            #print(out)
            #prediction_list = np.append([prediction_list], out)
            prediction_list = np.vstack([prediction_list, out])
            #print(prediction_list)
            #prediction_list = prediction_list[2*look_back - 1:]
        return prediction_list


    def predict_dates(num_prediction):
        last_date = data.index.values[-1]
        prediction_dates = pd.date_range(last_date, periods=num_prediction + 1).tolist()
        prediction_dates.pop(0)
        return prediction_dates



    num_prediction = 10
    forecast = (predict(num_prediction, model))[-10:]
    forecast = np.delete(forecast,slice(1,close_train.shape[1]),1)
    forecast = forecast.reshape((-1))

    forecast_dates = predict_dates(num_prediction)
    print(forecast)
    trace4 = go.Scatter(
        x=forecast_dates,
        y=forecast,
        mode='lines',
        name='Future Prediction'
    )
    fig = go.Figure(data=[trace1, trace2, trace3, trace4], layout=layout)
    fig.show()

    from sklearn.metrics import mean_absolute_error

    score = mean_absolute_error(test_price[:-look_back], prediction)
    print('MAE:', score)

    mae_list.append(score)
    
import statistics
print(
    '\nMinimum of mae: ',min(mae_list),
    '\nAverage of mae: ',statistics.mean(mae_list),
    '\nMaximum of mae: ',max(mae_list)
     )
# Out:
# Epoch 1/25
# 50/50 [==============================] - 1s 6ms/step - loss: 1810.0135
# Epoch 2/25
# 50/50 [==============================] - 0s 6ms/step - loss: 978.9349
# Epoch 3/25
# 50/50 [==============================] - 0s 5ms/step - loss: 849.3204
# Epoch 4/25
# 50/50 [==============================] - 0s 4ms/step - loss: 813.1575
# Epoch 5/25
# 50/50 [==============================] - 0s 6ms/step - loss: 754.0611
# Epoch 6/25
# 50/50 [==============================] - 0s 4ms/step - loss: 760.5867
# Epoch 7/25
# 50/50 [==============================] - 0s 5ms/step - loss: 751.1498
# Epoch 8/25
# 50/50 [==============================] - 0s 4ms/step - loss: 739.0253
# Epoch 9/25
# 50/50 [==============================] - 0s 4ms/step - loss: 723.2692
# Epoch 10/25
# 50/50 [==============================] - 0s 5ms/step - loss: 735.8268
# Epoch 11/25
# 50/50 [==============================] - 0s 6ms/step - loss: 705.6257
# Epoch 12/25
# 50/50 [==============================] - 0s 5ms/step - loss: 683.8422
# Epoch 13/25
# 50/50 [==============================] - 0s 5ms/step - loss: 688.9163
# Epoch 14/25
# 50/50 [==============================] - 0s 5ms/step - loss: 700.3093
# Epoch 15/25
# 50/50 [==============================] - 0s 5ms/step - loss: 683.1398
# Epoch 16/25
# 50/50 [==============================] - 0s 5ms/step - loss: 682.4674
# Epoch 17/25
# 50/50 [==============================] - 0s 5ms/step - loss: 695.6349
# Epoch 18/25
# 50/50 [==============================] - 0s 4ms/step - loss: 700.8724
# Epoch 19/25
# 50/50 [==============================] - 0s 4ms/step - loss: 692.4746
# Epoch 20/25
# 50/50 [==============================] - 0s 5ms/step - loss: 691.0488
# Epoch 21/25
# 50/50 [==============================] - 0s 5ms/step - loss: 701.0629
# Epoch 22/25
# 50/50 [==============================] - 0s 6ms/step - loss: 693.3583
# Epoch 23/25
# 50/50 [==============================] - 0s 6ms/step - loss: 689.8657
# Epoch 24/25
# 50/50 [==============================] - 0s 5ms/step - loss: 680.0789
# Epoch 25/25
# 50/50 [==============================] - 0s 5ms/step - loss: 674.0571
#
# Head of validation results:
#  [[181.27687]
#  [181.38086]
#  [181.95328]
#  [180.60907]
#  [180.09694]]
# <div>                            <div id="8b243a6f-204c-4534-8452-7d7ed9ab522e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8b243a6f-204c-4534-8452-7d7ed9ab522e")) {                    Plotly.newPlot(                        "8b243a6f-204c-4534-8452-7d7ed9ab522e",                        [{"mode":"lines","name":"Data","x":["2018-01-02T00:00:00","2018-01-03T00:00:00","2018-01-04T00:00:00","2018-01-05T00:00:00","2018-01-08T00:00:00","2018-01-09T00:00:00","2018-01-10T00:00:00","2018-01-11T00:00:00","2018-01-12T00:00:00","2018-01-16T00:00:00","2018-01-17T00:00:00","2018-01-18T00:00:00","2018-01-19T00:00:00","2018-01-22T00:00:00","2018-01-23T00:00:00","2018-01-24T00:00:00","2018-01-25T00:00:00","2018-01-26T00:00:00","2018-01-29T00:00:00","2018-01-30T00:00:00","2018-01-31T00:00:00","2018-02-01T00:00:00","2018-02-02T00:00:00","2018-02-05T00:00:00","2018-02-06T00:00:00","2018-02-07T00:00:00","2018-02-08T00:00:00","2018-02-09T00:00:00","2018-02-12T00:00:00","2018-02-13T00:00:00","2018-02-14T00:00:00","2018-02-15T00:00:00","2018-02-16T00:00:00","2018-02-20T00:00:00","2018-02-21T00:00:00","2018-02-22T00:00:00","2018-02-23T00:00:00","2018-02-26T00:00:00","2018-02-27T00:00:00","2018-02-28T00:00:00","2018-03-01T00:00:00","2018-03-02T00:00:00","2018-03-05T00:00:00","2018-03-06T00:00:00","2018-03-07T00:00:00","2018-03-08T00:00:00","2018-03-09T00:00:00","2018-03-12T00:00:00","2018-03-13T00:00:00","2018-03-14T00:00:00","2018-03-15T00:00:00","2018-03-16T00:00:00","2018-03-19T00:00:00","2018-03-20T00:00:00","2018-03-21T00:00:00","2018-03-22T00:00:00","2018-03-23T00:00:00","2018-03-26T00:00:00","2018-03-27T00:00:00","2018-03-28T00:00:00","2018-03-29T00:00:00","2018-04-02T00:00:00","2018-04-03T00:00:00","2018-04-04T00:00:00","2018-04-05T00:00:00","2018-04-06T00:00:00","2018-04-09T00:00:00","2018-04-10T00:00:00","2018-04-11T00:00:00","2018-04-12T00:00:00","2018-04-13T00:00:00","2018-04-16T00:00:00","2018-04-17T00:00:00","2018-04-18T00:00:00","2018-04-19T00:00:00","2018-04-20T00:00:00","2018-04-23T00:00:00","2018-04-24T00:00:00","2018-04-25T00:00:00","2018-04-26T00:00:00","2018-04-27T00:00:00","2018-04-30T00:00:00","2018-05-01T00:00:00","2018-05-02T00:00:00","2018-05-03T00:00:00","2018-05-04T00:00:00","2018-05-07T00:00:00","2018-05-08T00:00:00","2018-05-09T00:00:00","2018-05-10T00:00:00","2018-05-11T00:00:00","2018-05-14T00:00:00","2018-05-15T00:00:00","2018-05-16T00:00:00","2018-05-17T00:00:00","2018-05-18T00:00:00","2018-05-21T00:00:00","2018-05-22T00:00:00","2018-05-23T00:00:00","2018-05-24T00:00:00","2018-05-25T00:00:00","2018-05-29T00:00:00","2018-05-30T00:00:00","2018-05-31T00:00:00","2018-06-01T00:00:00","2018-06-04T00:00:00","2018-06-05T00:00:00","2018-06-06T00:00:00","2018-06-07T00:00:00","2018-06-08T00:00:00","2018-06-11T00:00:00","2018-06-12T00:00:00","2018-06-13T00:00:00","2018-06-14T00:00:00","2018-06-15T00:00:00","2018-06-18T00:00:00","2018-06-19T00:00:00","2018-06-20T00:00:00","2018-06-21T00:00:00","2018-06-22T00:00:00","2018-06-25T00:00:00","2018-06-26T00:00:00","2018-06-27T00:00:00","2018-06-28T00:00:00","2018-06-29T00:00:00","2018-07-02T00:00:00","2018-07-03T00:00:00","2018-07-05T00:00:00","2018-07-06T00:00:00","2018-07-09T00:00:00","2018-07-10T00:00:00","2018-07-11T00:00:00","2018-07-12T00:00:00","2018-07-13T00:00:00","2018-07-16T00:00:00","2018-07-17T00:00:00","2018-07-18T00:00:00","2018-07-19T00:00:00","2018-07-20T00:00:00","2018-07-23T00:00:00","2018-07-24T00:00:00","2018-07-25T00:00:00","2018-07-26T00:00:00","2018-07-27T00:00:00","2018-07-30T00:00:00","2018-07-31T00:00:00","2018-08-01T00:00:00","2018-08-02T00:00:00","2018-08-03T00:00:00","2018-08-06T00:00:00","2018-08-07T00:00:00","2018-08-08T00:00:00","2018-08-09T00:00:00","2018-08-10T00:00:00","2018-08-13T00:00:00","2018-08-14T00:00:00","2 ...
# [96.32107544 95.19729614 65.88130188 58.73527908 49.6634903  43.24917603
#  36.73575211 34.83288574 32.4962883  25.68606186]
# <div>                            <div id="23ec72a8-f472-4730-9d35-ca6c60e3ef3b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("23ec72a8-f472-4730-9d35-ca6c60e3ef3b")) {                    Plotly.newPlot(                        "23ec72a8-f472-4730-9d35-ca6c60e3ef3b",                        [{"mode":"lines","name":"Data","x":["2018-01-02T00:00:00","2018-01-03T00:00:00","2018-01-04T00:00:00","2018-01-05T00:00:00","2018-01-08T00:00:00","2018-01-09T00:00:00","2018-01-10T00:00:00","2018-01-11T00:00:00","2018-01-12T00:00:00","2018-01-16T00:00:00","2018-01-17T00:00:00","2018-01-18T00:00:00","2018-01-19T00:00:00","2018-01-22T00:00:00","2018-01-23T00:00:00","2018-01-24T00:00:00","2018-01-25T00:00:00","2018-01-26T00:00:00","2018-01-29T00:00:00","2018-01-30T00:00:00","2018-01-31T00:00:00","2018-02-01T00:00:00","2018-02-02T00:00:00","2018-02-05T00:00:00","2018-02-06T00:00:00","2018-02-07T00:00:00","2018-02-08T00:00:00","2018-02-09T00:00:00","2018-02-12T00:00:00","2018-02-13T00:00:00","2018-02-14T00:00:00","2018-02-15T00:00:00","2018-02-16T00:00:00","2018-02-20T00:00:00","2018-02-21T00:00:00","2018-02-22T00:00:00","2018-02-23T00:00:00","2018-02-26T00:00:00","2018-02-27T00:00:00","2018-02-28T00:00:00","2018-03-01T00:00:00","2018-03-02T00:00:00","2018-03-05T00:00:00","2018-03-06T00:00:00","2018-03-07T00:00:00","2018-03-08T00:00:00","2018-03-09T00:00:00","2018-03-12T00:00:00","2018-03-13T00:00:00","2018-03-14T00:00:00","2018-03-15T00:00:00","2018-03-16T00:00:00","2018-03-19T00:00:00","2018-03-20T00:00:00","2018-03-21T00:00:00","2018-03-22T00:00:00","2018-03-23T00:00:00","2018-03-26T00:00:00","2018-03-27T00:00:00","2018-03-28T00:00:00","2018-03-29T00:00:00","2018-04-02T00:00:00","2018-04-03T00:00:00","2018-04-04T00:00:00","2018-04-05T00:00:00","2018-04-06T00:00:00","2018-04-09T00:00:00","2018-04-10T00:00:00","2018-04-11T00:00:00","2018-04-12T00:00:00","2018-04-13T00:00:00","2018-04-16T00:00:00","2018-04-17T00:00:00","2018-04-18T00:00:00","2018-04-19T00:00:00","2018-04-20T00:00:00","2018-04-23T00:00:00","2018-04-24T00:00:00","2018-04-25T00:00:00","2018-04-26T00:00:00","2018-04-27T00:00:00","2018-04-30T00:00:00","2018-05-01T00:00:00","2018-05-02T00:00:00","2018-05-03T00:00:00","2018-05-04T00:00:00","2018-05-07T00:00:00","2018-05-08T00:00:00","2018-05-09T00:00:00","2018-05-10T00:00:00","2018-05-11T00:00:00","2018-05-14T00:00:00","2018-05-15T00:00:00","2018-05-16T00:00:00","2018-05-17T00:00:00","2018-05-18T00:00:00","2018-05-21T00:00:00","2018-05-22T00:00:00","2018-05-23T00:00:00","2018-05-24T00:00:00","2018-05-25T00:00:00","2018-05-29T00:00:00","2018-05-30T00:00:00","2018-05-31T00:00:00","2018-06-01T00:00:00","2018-06-04T00:00:00","2018-06-05T00:00:00","2018-06-06T00:00:00","2018-06-07T00:00:00","2018-06-08T00:00:00","2018-06-11T00:00:00","2018-06-12T00:00:00","2018-06-13T00:00:00","2018-06-14T00:00:00","2018-06-15T00:00:00","2018-06-18T00:00:00","2018-06-19T00:00:00","2018-06-20T00:00:00","2018-06-21T00:00:00","2018-06-22T00:00:00","2018-06-25T00:00:00","2018-06-26T00:00:00","2018-06-27T00:00:00","2018-06-28T00:00:00","2018-06-29T00:00:00","2018-07-02T00:00:00","2018-07-03T00:00:00","2018-07-05T00:00:00","2018-07-06T00:00:00","2018-07-09T00:00:00","2018-07-10T00:00:00","2018-07-11T00:00:00","2018-07-12T00:00:00","2018-07-13T00:00:00","2018-07-16T00:00:00","2018-07-17T00:00:00","2018-07-18T00:00:00","2018-07-19T00:00:00","2018-07-20T00:00:00","2018-07-23T00:00:00","2018-07-24T00:00:00","2018-07-25T00:00:00","2018-07-26T00:00:00","2018-07-27T00:00:00","2018-07-30T00:00:00","2018-07-31T00:00:00","2018-08-01T00:00:00","2018-08-02T00:00:00","2018-08-03T00:00:00","2018-08-06T00:00:00","2018-08-07T00:00:00","2018-08-08T00:00:00","2018-08-09T00:00:00","2018-08-10T00:00:00","2018-08-13T00:00:00","2018-08-14T00:00:00","2 ...
# MAE: 6.965229903117264
# Epoch 1/25
# 50/50 [==============================] - 2s 6ms/step - loss: 1731.6268
# Epoch 2/25
# 50/50 [==============================] - 0s 7ms/step - loss: 1142.2081
# Epoch 3/25
# 50/50 [==============================] - 0s 8ms/step - loss: 905.9532
# Epoch 4/25
# 50/50 [==============================] - 0s 6ms/step - loss: 843.3491
# Epoch 5/25
# 50/50 [==============================] - 0s 6ms/step - loss: 820.8538
# Epoch 6/25
# 50/50 [==============================] - 0s 5ms/step - loss: 787.0637
# Epoch 7/25
# 50/50 [==============================] - 0s 5ms/step - loss: 823.3156
# Epoch 8/25
# 50/50 [==============================] - 0s 8ms/step - loss: 762.8291
# Epoch 12/25
# 50/50 [==============================] - 0s 6ms/step - loss: 729.5560
# Epoch 13/25
# 50/50 [==============================] - 0s 4ms/step - loss: 724.7717
# Epoch 14/25
# 50/50 [==============================] - 0s 4ms/step - loss: 723.8120
# Epoch 15/25
# 50/50 [==============================] - 0s 4ms/step - loss: 714.1736
# Epoch 16/25
# 50/50 [==============================] - 0s 5ms/step - loss: 722.7068
# Epoch 17/25
# 50/50 [==============================] - 0s 4ms/step - loss: 699.0682
# Epoch 18/25
# 50/50 [==============================] - 0s 5ms/step - loss: 694.4460
# Epoch 19/25
# 50/50 [==============================] - 0s 5ms/step - loss: 705.7922
# Epoch 20/25
# 50/50 [==============================] - 0s 7ms/step - loss: 696.8157
# Epoch 21/25
# 50/50 [==============================] - 0s 5ms/step - loss: 697.3421
# Epoch 22/25
# 50/50 [==============================] - 0s 5ms/step - loss: 677.8552
# Epoch 23/25
# 50/50 [==============================] - 0s 4ms/step - loss: 683.4384
# Epoch 24/25
# 50/50 [==============================] - 0s 5ms/step - loss: 694.1461
# Epoch 25/25
# 50/50 [==============================] - 0s 5ms/step - loss: 684.8807
#
# Head of validation results:
#  [[178.06534]
#  [177.90242]
#  [179.49893]
#  [178.37782]
#  [177.85666]]
# <div>                            <div id="e4111b97-2f15-45de-afdc-8cd15649ac20" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e4111b97-2f15-45de-afdc-8cd15649ac20")) {                    Plotly.newPlot(                        "e4111b97-2f15-45de-afdc-8cd15649ac20",                        [{"mode":"lines","name":"Data","x":["2018-01-02T00:00:00","2018-01-03T00:00:00","2018-01-04T00:00:00","2018-01-05T00:00:00","2018-01-08T00:00:00","2018-01-09T00:00:00","2018-01-10T00:00:00","2018-01-11T00:00:00","2018-01-12T00:00:00","2018-01-16T00:00:00","2018-01-17T00:00:00","2018-01-18T00:00:00","2018-01-19T00:00:00","2018-01-22T00:00:00","2018-01-23T00:00:00","2018-01-24T00:00:00","2018-01-25T00:00:00","2018-01-26T00:00:00","2018-01-29T00:00:00","2018-01-30T00:00:00","2018-01-31T00:00:00","2018-02-01T00:00:00","2018-02-02T00:00:00","2018-02-05T00:00:00","2018-02-06T00:00:00","2018-02-07T00:00:00","2018-02-08T00:00:00","2018-02-09T00:00:00","2018-02-12T00:00:00","2018-02-13T00:00:00","2018-02-14T00:00:00","2018-02-15T00:00:00","2018-02-16T00:00:00","2018-02-20T00:00:00","2018-02-21T00:00:00","2018-02-22T00:00:00","2018-02-23T00:00:00","2018-02-26T00:00:00","2018-02-27T00:00:00","2018-02-28T00:00:00","2018-03-01T00:00:00","2018-03-02T00:00:00","2018-03-05T00:00:00","2018-03-06T00:00:00","2018-03-07T00:00:00","2018-03-08T00:00:00","2018-03-09T00:00:00","2018-03-12T00:00:00","2018-03-13T00:00:00","2018-03-14T00:00:00","2018-03-15T00:00:00","2018-03-16T00:00:00","2018-03-19T00:00:00","2018-03-20T00:00:00","2018-03-21T00:00:00","2018-03-22T00:00:00","2018-03-23T00:00:00","2018-03-26T00:00:00","2018-03-27T00:00:00","2018-03-28T00:00:00","2018-03-29T00:00:00","2018-04-02T00:00:00","2018-04-03T00:00:00","2018-04-04T00:00:00","2018-04-05T00:00:00","2018-04-06T00:00:00","2018-04-09T00:00:00","2018-04-10T00:00:00","2018-04-11T00:00:00","2018-04-12T00:00:00","2018-04-13T00:00:00","2018-04-16T00:00:00","2018-04-17T00:00:00","2018-04-18T00:00:00","2018-04-19T00:00:00","2018-04-20T00:00:00","2018-04-23T00:00:00","2018-04-24T00:00:00","2018-04-25T00:00:00","2018-04-26T00:00:00","2018-04-27T00:00:00","2018-04-30T00:00:00","2018-05-01T00:00:00","2018-05-02T00:00:00","2018-05-03T00:00:00","2018-05-04T00:00:00","2018-05-07T00:00:00","2018-05-08T00:00:00","2018-05-09T00:00:00","2018-05-10T00:00:00","2018-05-11T00:00:00","2018-05-14T00:00:00","2018-05-15T00:00:00","2018-05-16T00:00:00","2018-05-17T00:00:00","2018-05-18T00:00:00","2018-05-21T00:00:00","2018-05-22T00:00:00","2018-05-23T00:00:00","2018-05-24T00:00:00","2018-05-25T00:00:00","2018-05-29T00:00:00","2018-05-30T00:00:00","2018-05-31T00:00:00","2018-06-01T00:00:00","2018-06-04T00:00:00","2018-06-05T00:00:00","2018-06-06T00:00:00","2018-06-07T00:00:00","2018-06-08T00:00:00","2018-06-11T00:00:00","2018-06-12T00:00:00","2018-06-13T00:00:00","2018-06-14T00:00:00","2018-06-15T00:00:00","2018-06-18T00:00:00","2018-06-19T00:00:00","2018-06-20T00:00:00","2018-06-21T00:00:00","2018-06-22T00:00:00","2018-06-25T00:00:00","2018-06-26T00:00:00","2018-06-27T00:00:00","2018-06-28T00:00:00","2018-06-29T00:00:00","2018-07-02T00:00:00","2018-07-03T00:00:00","2018-07-05T00:00:00","2018-07-06T00:00:00","2018-07-09T00:00:00","2018-07-10T00:00:00","2018-07-11T00:00:00","2018-07-12T00:00:00","2018-07-13T00:00:00","2018-07-16T00:00:00","2018-07-17T00:00:00","2018-07-18T00:00:00","2018-07-19T00:00:00","2018-07-20T00:00:00","2018-07-23T00:00:00","2018-07-24T00:00:00","2018-07-25T00:00:00","2018-07-26T00:00:00","2018-07-27T00:00:00","2018-07-30T00:00:00","2018-07-31T00:00:00","2018-08-01T00:00:00","2018-08-02T00:00:00","2018-08-03T00:00:00","2018-08-06T00:00:00","2018-08-07T00:00:00","2018-08-08T00:00:00","2018-08-09T00:00:00","2018-08-10T00:00:00","2018-08-13T00:00:00","2018-08-14T00:00:00","2 ...
# [83.32051086 83.75944519 61.03344727 65.25384521 59.2652359  50.98797989
#  46.63448715 34.68976974 28.21549225 27.84580231]
# <div>                            <div id="8e77b1ce-9813-49b1-baab-1bd0d145cbad" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8e77b1ce-9813-49b1-baab-1bd0d145cbad")) {                    Plotly.newPlot(                        "8e77b1ce-9813-49b1-baab-1bd0d145cbad",                        [{"mode":"lines","name":"Data","x":["2018-01-02T00:00:00","2018-01-03T00:00:00","2018-01-04T00:00:00","2018-01-05T00:00:00","2018-01-08T00:00:00","2018-01-09T00:00:00","2018-01-10T00:00:00","2018-01-11T00:00:00","2018-01-12T00:00:00","2018-01-16T00:00:00","2018-01-17T00:00:00","2018-01-18T00:00:00","2018-01-19T00:00:00","2018-01-22T00:00:00","2018-01-23T00:00:00","2018-01-24T00:00:00","2018-01-25T00:00:00","2018-01-26T00:00:00","2018-01-29T00:00:00","2018-01-30T00:00:00","2018-01-31T00:00:00","2018-02-01T00:00:00","2018-02-02T00:00:00","2018-02-05T00:00:00","2018-02-06T00:00:00","2018-02-07T00:00:00","2018-02-08T00:00:00","2018-02-09T00:00:00","2018-02-12T00:00:00","2018-02-13T00:00:00","2018-02-14T00:00:00","2018-02-15T00:00:00","2018-02-16T00:00:00","2018-02-20T00:00:00","2018-02-21T00:00:00","2018-02-22T00:00:00","2018-02-23T00:00:00","2018-02-26T00:00:00","2018-02-27T00:00:00","2018-02-28T00:00:00","2018-03-01T00:00:00","2018-03-02T00:00:00","2018-03-05T00:00:00","2018-03-06T00:00:00","2018-03-07T00:00:00","2018-03-08T00:00:00","2018-03-09T00:00:00","2018-03-12T00:00:00","2018-03-13T00:00:00","2018-03-14T00:00:00","2018-03-15T00:00:00","2018-03-16T00:00:00","2018-03-19T00:00:00","2018-03-20T00:00:00","2018-03-21T00:00:00","2018-03-22T00:00:00","2018-03-23T00:00:00","2018-03-26T00:00:00","2018-03-27T00:00:00","2018-03-28T00:00:00","2018-03-29T00:00:00","2018-04-02T00:00:00","2018-04-03T00:00:00","2018-04-04T00:00:00","2018-04-05T00:00:00","2018-04-06T00:00:00","2018-04-09T00:00:00","2018-04-10T00:00:00","2018-04-11T00:00:00","2018-04-12T00:00:00","2018-04-13T00:00:00","2018-04-16T00:00:00","2018-04-17T00:00:00","2018-04-18T00:00:00","2018-04-19T00:00:00","2018-04-20T00:00:00","2018-04-23T00:00:00","2018-04-24T00:00:00","2018-04-25T00:00:00","2018-04-26T00:00:00","2018-04-27T00:00:00","2018-04-30T00:00:00","2018-05-01T00:00:00","2018-05-02T00:00:00","2018-05-03T00:00:00","2018-05-04T00:00:00","2018-05-07T00:00:00","2018-05-08T00:00:00","2018-05-09T00:00:00","2018-05-10T00:00:00","2018-05-11T00:00:00","2018-05-14T00:00:00","2018-05-15T00:00:00","2018-05-16T00:00:00","2018-05-17T00:00:00","2018-05-18T00:00:00","2018-05-21T00:00:00","2018-05-22T00:00:00","2018-05-23T00:00:00","2018-05-24T00:00:00","2018-05-25T00:00:00","2018-05-29T00:00:00","2018-05-30T00:00:00","2018-05-31T00:00:00","2018-06-01T00:00:00","2018-06-04T00:00:00","2018-06-05T00:00:00","2018-06-06T00:00:00","2018-06-07T00:00:00","2018-06-08T00:00:00","2018-06-11T00:00:00","2018-06-12T00:00:00","2018-06-13T00:00:00","2018-06-14T00:00:00","2018-06-15T00:00:00","2018-06-18T00:00:00","2018-06-19T00:00:00","2018-06-20T00:00:00","2018-06-21T00:00:00","2018-06-22T00:00:00","2018-06-25T00:00:00","2018-06-26T00:00:00","2018-06-27T00:00:00","2018-06-28T00:00:00","2018-06-29T00:00:00","2018-07-02T00:00:00","2018-07-03T00:00:00","2018-07-05T00:00:00","2018-07-06T00:00:00","2018-07-09T00:00:00","2018-07-10T00:00:00","2018-07-11T00:00:00","2018-07-12T00:00:00","2018-07-13T00:00:00","2018-07-16T00:00:00","2018-07-17T00:00:00","2018-07-18T00:00:00","2018-07-19T00:00:00","2018-07-20T00:00:00","2018-07-23T00:00:00","2018-07-24T00:00:00","2018-07-25T00:00:00","2018-07-26T00:00:00","2018-07-27T00:00:00","2018-07-30T00:00:00","2018-07-31T00:00:00","2018-08-01T00:00:00","2018-08-02T00:00:00","2018-08-03T00:00:00","2018-08-06T00:00:00","2018-08-07T00:00:00","2018-08-08T00:00:00","2018-08-09T00:00:00","2018-08-10T00:00:00","2018-08-13T00:00:00","2018-08-14T00:00:00","2 ...
# MAE: 7.76085897011332
# Epoch 1/25
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes, acd_record_initial_resource_uses)
#    1160
# -> 1161       func_outputs = python_func(*func_args, **func_kwargs)
#    1162
#
# ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py in wrapped_fn(*args, **kwds)
#     676         with OptionalXlaContext(compile_with_xla):
# --> 677           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     678         return out
#
# ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/framework/func_graph.py in autograph_handler(*args, **kwargs)
#    1135           try:
# -> 1136             return autograph.converted_call(
#    1137                 original_func,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     438       if kwargs is not None:
# --> 439         result = converted_f(*effective_args, **kwargs)
#     440       else:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training.py in tf__train_function(iterator)
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     330     logging.log(2, 'Allowlisted %s: from cache', f)
# --> 331     return _call_unconverted(f, args, kwargs, options, False)
#     332
#
# ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/autograph/impl/api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     458     return f(*args, **kwargs)
# --> 459   return f(*args)
#     460
#
# ~/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training.py in step_function(model, iterator)
#    1009       data = next(iterator)
# -> 1010       outputs = model.distribute_strategy.run(run_step, args=(data,))
#    1011       outputs = reduce_per_replica(
#
# ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/distribute/distribute_lib.py in run(***failed resolving arguments***)
#    1311           fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1312       return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#    1313
#
# ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/distribute/distribute_lib.py in call_for_each_replica(self, fn, args, kwargs)
#    2887     with self._container_strategy().scope():
# -> 2888       return self._call_for_each_replica(fn, args, kwargs)
#    2889
#
# ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/distribute/distribute_lib.py in _call_for_each_replica(self, fn, args, kwargs)
#    3688     with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 3689       return fn(*args, **kwargs)
#    3690
#
# ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     688         with conversion_ctx:
# --> 689           return converted_call(f, args, kwargs, options=options)
#     690       except Exception as e:  # pylint:disable=broad-except
#
# ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     376   if not options.user_requested and conversion.is_allowlisted(f):
# --> 377     return _call_unconverted(f, args, kwargs, options)
#     378
#
# ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/autograph/impl/api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     457   if kwargs is not None:
# --> 458     return f(*args, **kwargs)
#     459   return f(*args)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training.py in run_step(data)
#     999       def run_step(data):
# -> 1000         outputs = model.train_step(data)
#    1001         # Ensure counter is updated only if `train_step` succeeds.
#
# ~/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training.py in train_step(self, data)
#     862     # Run backwards pass.
# --> 863     self.optimizer.minimize(loss, self.trainable_variables, tape=tape)
#     864     return self.compute_metrics(x, y, y_pred, sample_weight)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/keras/optimizer_v2/optimizer_v2.py in minimize(self, loss, var_list, grad_loss, name, tape)
#     529     """
# --> 530     grads_and_vars = self._compute_gradients(
#     531         loss, var_list=var_list, grad_loss=grad_loss, tape=tape)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/keras/optimizer_v2/optimizer_v2.py in _compute_gradients(self, loss, var_list, grad_loss, tape)
#     582     with tf.name_scope(self._name + "/gradients"):
# --> 583       grads_and_vars = self._get_gradients(tape, loss, var_list, grad_loss)
#     584
#
# ~/opt/anaconda3/lib/python3.9/site-packages/keras/optimizer_v2/optimizer_v2.py in _get_gradients(self, tape, loss, var_list, grad_loss)
#     463     """Called in `minimize` to compute gradients from loss."""
# --> 464     grads = tape.gradient(loss, var_list, grad_loss)
#     465     return list(zip(grads, var_list))
#
# ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/backprop.py in gradient(self, target, sources, output_gradients, unconnected_gradients)
#    1080
# -> 1081     flat_grad = imperative_grad.imperative_grad(
#    1082         self._tape,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/imperative_grad.py in imperative_grad(tape, target, sources, output_gradients, sources_raw, unconnected_gradients)
#      66
# ---> 67   return pywrap_tfe.TFE_Py_TapeGradient(
#      68       tape._tape,  # pylint: disable=protected-access
#
# ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/backprop.py in _gradient_function(op_name, attr_tuple, num_inputs, inputs, outputs, out_grads, skip_input_indices, forward_pass_name_scope)
#     155     with ops.name_scope(gradient_name_scope):
# --> 156       return grad_fn(mock_op, *out_grads)
#     157   else:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/ops/while_v2.py in _WhileGrad(op, *grads)
#     437   grad_cond_name = util.unique_grad_fn_name(op.get_attr("cond").name)
# --> 438   cond_grad_graph = func_graph_module.func_graph_from_py_func(
#     439       grad_cond_name, grad_cond, loop_vars, {},
#
# ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes, acd_record_initial_resource_uses)
#    1074       kwarg_shapes = None
# -> 1075     func_args = _get_defun_inputs_from_args(
#    1076         args, arg_names, flat_shapes=arg_shapes)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/framework/func_graph.py in _get_defun_inputs_from_args(args, names, flat_shapes)
#    1312   """Maps Python function positional args to graph-construction inputs."""
# -> 1313   return _get_defun_inputs(
#    1314       args, names, structure=args, flat_shapes=flat_shapes)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/framework/func_graph.py in _get_defun_inputs(args, names, structure, flat_shapes)
#    1385         try:
# -> 1386           placeholder = graph_placeholder(
#    1387               arg.dtype, placeholder_shape,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/graph_only_ops.py in graph_placeholder(dtype, shape, name)
#      33   attrs = {"dtype": dtype_value, "shape": shape}
# ---> 34   op = g._create_op_internal(  # pylint: disable=protected-access
#      35       "Placeholder", [], [dtype], input_types=[],
#
# ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/framework/func_graph.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     692       captured_inputs.append(inp)
# --> 693     return super(FuncGraph, self)._create_op_internal(  # pylint: disable=protected-access
#     694         op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/framework/ops.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    3775     with self._mutation_lock():
# -> 3776       ret = Operation(
#    3777           node_def,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/framework/ops.py in __init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    2186       output_type = pywrap_tf_session.TF_OperationOutputType(tf_output)
# -> 2187       tensor = Tensor._create_with_tf_output(self, i, output_type, tf_output)  # pylint: disable=protected-access
#    2188       self._outputs.append(tensor)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/framework/ops.py in _create_with_tf_output(op, value_index, dtype, tf_output)
#     516   def _create_with_tf_output(op, value_index, dtype, tf_output):
# --> 517     ret = Tensor(op, value_index, dtype)
#     518     ret._tf_output = tf_output
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/ym/67x0srsx2ln9vy4qtlvtdv500000gn/T/ipykernel_28440/2821535715.py in <module>
#      40
#      41     num_epochs = 25
# ---> 42     model.fit(train_generator, epochs=num_epochs, verbose=1)
#      43
#      44     rsi_array = rsi.to_numpy()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1382                 _r=1):
#    1383               callbacks.on_train_batch_begin(step)
# -> 1384               tmp_logs = self.train_function(iterator)
#    1385               if data_handler.should_sync:
#    1386                 context.async_wait()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     978         # Lifting succeeded, so variables are initialized and we can run the
#     979         # stateless function.
# --> 980         return self._stateless_fn(*args, **kwds)
#     981     else:
#     982       _, _, _, filtered_flat_args = \
#
# ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2953     with self._lock:
#    2954       (graph_function,
# -> 2955        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2956     return graph_function._call_flat(
#    2957         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#
# ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3290
#    3291           self._function_cache.add_call_context(cache_key.call_context)
# -> 3292           graph_function = self._create_graph_function(args, kwargs)
#    3293           self._function_cache.add(cache_key, cache_key_deletion_observer,
#    3294                                    graph_function)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3128     arg_names = base_arg_names + missing_arg_names
#    3129     graph_function = ConcreteFunction(
# -> 3130         func_graph_module.func_graph_from_py_func(
#    3131             self._name,
#    3132             self._python_function,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes, acd_record_initial_resource_uses)
#    1200         if x is not None)
#    1201
# -> 1202     func_graph.variables = variables
#    1203
#    1204   if add_control_dependencies:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/framework/auto_control_deps.py in __exit__(self, unused_type, unused_value, unused_traceback)
#     463       # Check for any resource inputs. If we find any, we update control_inputs
#     464       # and last_write_to_resource.
# --> 465       for inp, resource_type in _get_resource_inputs(op):
#     466         is_read = resource_type == ResourceType.READ_ONLY
#     467         input_id = ops.tensor_id(inp)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/framework/auto_control_deps.py in _get_resource_inputs(op)
#     670       # TODO(srbs): An alternate would be to just compare the old and new set
#     671       # but that may not be as fast.
# --> 672       updated = _acd_resource_resolvers_registry.lookup(key)(op, reads, writes)
#     673       if updated:
#     674         # Conservatively remove any resources from `reads` that are also writes.
#
# ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/tpu/tpu.py in tpu_replicated_input_resolver(op, resource_reads, resource_writes)
#     275     return to_add or to_remove
#     276
# --> 277   return bool(replace_with_unreplicated_resources(resource_reads) or
#     278               replace_with_unreplicated_resources(resource_writes))
#     279
#
# ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/tpu/tpu.py in replace_with_unreplicated_resources(resource_inputs)
#     266     to_remove = []
#     267     to_add = []
# --> 268     for resource in resource_inputs:
#     269       if resource.op.type == "TPUReplicatedInput":
#     270         to_remove.append(resource)
#
# KeyboardInterrupt:
