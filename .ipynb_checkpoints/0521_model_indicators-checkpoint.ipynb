# %%
from pandas_datareader.data import DataReader
import numpy as np
import plotly.graph_objs as go
import pandas as pd
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import yfinance as yf
from stockstats import StockDataFrame
from sklearn.preprocessing import MinMaxScaler

def predict(num_prediction, model):
    prediction_list = test_X[-2:]

    for i in range(num_prediction):
        x = prediction_list[-1:]
        out = [float(model.predict(x)[-1:])]
        x = x.reshape(-1)
        for var in range(n_vars-1):
            out.append(x[var+1] + x[var+1] - prediction_list[-2,0,var+1])
        prediction_list = prediction_list.reshape(i+2,prediction_list.shape[2])
        prediction_list = np.vstack([prediction_list, out])
        prediction_list = prediction_list.reshape(i+3,1,prediction_list.shape[1])
    
    return prediction_list


def predict_dates(num_prediction):
    last_date = data.index.values[-1]
    prediction_dates = pd.date_range(last_date, periods=num_prediction + 1).tolist()
    prediction_dates.pop(0)
    return prediction_dates


user_input = input('Input the ticker:')
df = DataReader(user_input, data_source='yahoo', start='2018-01-01', end=datetime.now()- timedelta(days=6))
# Create a new dataframe with only the 'Close column 
data = df.filter(['Close'])
print(data)

# Convert the dataframe to a numpy array
dataset = data.values
date = data.index

date_number = np.linspace(1,len(date),len(date))
dataset = dataset.flatten()
mymodel = np.poly1d(np.polyfit(date_number, dataset, 3))
plt.figure(figsize=(12, 10), dpi=80)
plt.plot(date, dataset)
plt.plot(date, mymodel(date_number))
plt.show()
# Out:
# Input the ticker:aapl
#                  Close
# Date
# 2018-01-02   43.064999
# 2018-01-03   43.057499
# 2018-01-04   43.257500
# 2018-01-05   43.750000
# 2018-01-08   43.587502
# ...                ...
# 2022-05-23  143.110001
# 2022-05-24  140.360001
# 2022-05-25  140.520004
# 2022-05-26  143.779999
# 2022-05-27  149.639999
#
# [1110 rows x 1 columns]
#                  Close
# Date
# 2018-01-02   43.064999
# 2018-01-03   43.057499
# 2018-01-04   43.257500
# 2018-01-05   43.750000
# 2018-01-08   43.587502
# ...                ...
# 2022-05-16  145.539993
# 2022-05-17  149.240005
# 2022-05-18  140.820007
# 2022-05-19  137.350006
# 2022-05-20  137.589996
#
# [1105 rows x 1 columns]

# %%
close_data_df = StockDataFrame.retype(df)

# print(stock)
# rsi = stock['rsi']
# kdj = stock['kdjj']
# macd = stock['macds']
# boll = stock['boll']
# ma = stock['tema']

# rsi = rsi[2:]
# kdj = kdj[2:]
# macd = macd[2:]
# boll = boll[2:]
# ma = ma[2:]

# close_data_df = pd.concat([data[2:],rsi,boll,ma,kdj,macd],axis=1)

scaler = MinMaxScaler(feature_range=(0, 1))
scaled= scaler.fit_transform(close_data_df[['close']])

scaled_df = pd.DataFrame(scaled)
scaled_df.index = close_data_df.index
#scaled_df.columns = ['Close','rsi_6','boll','tema']
scaled_df.columns = ['close']

close_data_df = close_data_df.filter(['kdjj'])
close_data_df = pd.concat([scaled_df,close_data_df],axis=1)
# close_data_df = scaled_df

print(close_data_df.corr())
close_data_df.head()
# Out:
#           close      kdjj
# close  1.000000 -0.043102
# kdjj  -0.043102  1.000000
#                close       kdjj
# Date
# 2018-01-02  0.051327  87.865281
# 2018-01-03  0.051276  72.809442
# 2018-01-04  0.052641  76.028458
# 2018-01-05  0.056004  94.568414
# 2018-01-08  0.054895  92.015960

# %%
from sklearn.metrics import mean_absolute_error
import statistics
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout

score_list = []
forecast_list = []
num_trials = 11
n_in=1
n_out=1
split_percent = 0.8
num_prediction = 10
dropnan = True
num_epochs = 25

for _ in range(num_trials):
    n_vars = 1 if type(data) is list else close_data_df.shape[1]
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(close_data_df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(close_data_df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
            # put it all together
    supervised_df = pd.concat(cols, axis=1)
    supervised_df.columns = names
    # drop rows with NaN values
    if dropnan:
        supervised_df.dropna(inplace=True)
    supervised_df = supervised_df.drop(supervised_df.columns[-n_vars+1:], axis=1)
    # return agg

    #series_to_supervised(close_data_df)
    supervised_df.head()

    supervised_data = supervised_df.to_numpy()

    split = int(split_percent * len(close_data_df))

    supervised_train = supervised_data[:split]
    supervised_test = supervised_data[split:]

    train_X, train_y = supervised_train[:, :-1], supervised_train[:, -1]
    test_X, test_y = supervised_test[:, :-1], supervised_test[:, -1]
    # reshape input to be 3D [samples, timesteps, features]
    train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
    test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))

    close_data = close_data_df.to_numpy()

    date_train = date[:split]
    date_test = date[split+2:]

    model = Sequential()

    model.add(
        LSTM(50,
             activation='relu',
             #return_sequences=True,
             input_shape=(train_X.shape[1], train_X.shape[2]))
    )
    model.add(Dropout(0.2))

    # model.add(LSTM(128, return_sequences=True, input_shape= (date_train.shape[0], 1)))
    # model.add(LSTM(64, return_sequences=False))
    # model.add(Dense(25))

    model.add(Dense(units=1))
    model.compile(optimizer='adam', loss='mse')

    history = model.fit(train_X, train_y, epochs=num_epochs, batch_size=20, verbose=1, validation_data=(test_X, test_y))

    yhat = model.predict(test_X)
    yhat_df = pd.DataFrame(yhat)
    yhat_df.index = close_data_df.index[split+1:]
    yhat_df.columns = ['Close']
    print(yhat_df)

    new_test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))
    inv_yhat = np.concatenate((yhat_df, new_test_X[:,1:scaled_df.shape[1]]), axis=1)
    inv_yhat = scaler.inverse_transform(inv_yhat)
    print('\nHead of "inv_yhat":\n',inv_yhat[:5])

    test_y = test_y.reshape((test_X.shape[0], test_X.shape[1]))
    inv_testy = np.hstack([test_y,np.zeros(test_y.shape)])
    inv_testy = scaler.inverse_transform(inv_testy)
    inv_testy = inv_testy[:,:1]
    print('\nHead of "inv_testy":\n',inv_testy[:5])

    train = train_y.reshape(train_y.shape[0],1)
    train = np.hstack([train, np.zeros(train.shape)])
    train = scaler.inverse_transform(train)
    train = np.delete(train,[1,scaled_df.shape[1]],1)
    train = train.reshape((-1))
    test = inv_testy.reshape((-1))
    prediction = inv_yhat[:,:1]
    prediction = prediction.reshape((-1))

    trace1 = go.Scatter(
        x=date_train,
        y=train,
        mode='lines',
        name='Data'
    )
    trace2 = go.Scatter(
        x=date_test,
        y=prediction,
        mode='lines',
        name='Prediction'
    )
    trace3 = go.Scatter(
        x=date_test,
        y=test,
        mode='lines',
        name='Ground Truth'
    )
    layout = go.Layout(
        title="Stock",
        xaxis={'title': "Date"},
        yaxis={'title': "Close"}
    )

    forecast = (predict(num_prediction, model))
    forecast = forecast.reshape(num_prediction + 2,forecast.shape[2])
#     forecast = np.delete(forecast,slice(-(close_data_df.shape[1] - scaled_df.shape[1]),forecast.shape[1]),1)
    forecast = np.delete(forecast,slice(scaled_df.shape[1],forecast.shape[1]),1)
    print(close_data_df.shape[1] - scaled_df.shape[1])
    forecast = scaler.inverse_transform(forecast)
    forecast = np.delete(forecast,slice(1,forecast.shape[1]),1)
    forecast = forecast.reshape((-1))
    forecast_list = np.append(forecast_list,np.array([forecast]))
    
    forecast_dates = predict_dates(num_prediction)
    trace4 = go.Scatter(
        x=forecast_dates,
        y=forecast,
        mode='lines',
        name='Future Prediction'
    )
    fig = go.Figure(data=[trace1, trace2, trace3, trace4], layout=layout)
    fig.show()

    score = mean_absolute_error(test, prediction)
    score_list.append(score)
    
print(
'\nMinimum of mae: ',min(score_list),
'\nAverage of mae: ',(sum(score_list) - max(score_list))/(len(score_list) - 1),
'\nMaximum of mae: ',max(score_list)
 )

forecast_list = np.reshape(forecast_list,[num_trials,num_prediction + 2])
forecast_5days = forecast_list[:,2:7]
var = np.var(forecast_5days,axis = 1)
maxindex = np.argmax(var)
forecast_5days = np.delete(forecast_5days,maxindex,0)


print(forecast_5days)
# Out:
# Epoch 1/25
# 45/45 [==============================] - 1s 7ms/step - loss: 2.8304 - val_loss: 0.4020
# Epoch 2/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.7847 - val_loss: 0.2432
# Epoch 3/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.2346 - val_loss: 0.3021
# Epoch 4/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1060 - val_loss: 0.2763
# Epoch 5/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0675 - val_loss: 0.2675
# Epoch 6/25
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0520 - val_loss: 0.2220
# Epoch 7/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0479 - val_loss: 0.2137
# Epoch 8/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0454 - val_loss: 0.1752
# Epoch 9/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0379 - val_loss: 0.1855
# Epoch 10/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0336 - val_loss: 0.1204
# Epoch 11/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0280 - val_loss: 0.0914
# Epoch 12/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0230 - val_loss: 0.0609
# Epoch 13/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0194 - val_loss: 0.0447
# Epoch 14/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0170 - val_loss: 0.0272
# Epoch 15/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0127 - val_loss: 0.0166
# Epoch 16/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0111 - val_loss: 0.0107
# Epoch 17/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0099 - val_loss: 0.0122
# Epoch 18/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0092 - val_loss: 0.0056
# Epoch 19/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0088 - val_loss: 0.0071
# Epoch 20/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0081 - val_loss: 0.0044
# Epoch 21/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0079 - val_loss: 0.0053
# Epoch 22/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0085 - val_loss: 0.0030
# Epoch 23/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0066 - val_loss: 0.0049
# Epoch 24/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0073 - val_loss: 0.0093
# Epoch 25/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0072 - val_loss: 0.0033
#                Close
# Date
# 2021-07-09  0.694569
# 2021-07-12  0.707295
# 2021-07-13  0.703257
# 2021-07-14  0.711347
# 2021-07-15  0.734788
# ...              ...
# 2022-05-16  0.748567
# 2022-05-17  0.734730
# 2022-05-18  0.749726
# 2022-05-19  0.698362
# 2022-05-20  0.663833
#
# [220 rows x 1 columns]
#
# Head of "inv_yhat":
#  [[137.27581604]
#  [139.13965539]
#  [138.5482957 ]
#  [139.73316263]
#  [143.16640112]]
#
# Head of "inv_testy":
#  [[145.11000061]
#  [144.5       ]
#  [145.63999939]
#  [149.1499939 ]
#  [148.47999573]]
# 1
# <div>                            <div id="94aab5d7-ce42-4403-9a4f-70593d69e513" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("94aab5d7-ce42-4403-9a4f-70593d69e513")) {                    Plotly.newPlot(                        "94aab5d7-ce42-4403-9a4f-70593d69e513",                        [{"mode":"lines","name":"Data","x":["2018-01-02T00:00:00","2018-01-03T00:00:00","2018-01-04T00:00:00","2018-01-05T00:00:00","2018-01-08T00:00:00","2018-01-09T00:00:00","2018-01-10T00:00:00","2018-01-11T00:00:00","2018-01-12T00:00:00","2018-01-16T00:00:00","2018-01-17T00:00:00","2018-01-18T00:00:00","2018-01-19T00:00:00","2018-01-22T00:00:00","2018-01-23T00:00:00","2018-01-24T00:00:00","2018-01-25T00:00:00","2018-01-26T00:00:00","2018-01-29T00:00:00","2018-01-30T00:00:00","2018-01-31T00:00:00","2018-02-01T00:00:00","2018-02-02T00:00:00","2018-02-05T00:00:00","2018-02-06T00:00:00","2018-02-07T00:00:00","2018-02-08T00:00:00","2018-02-09T00:00:00","2018-02-12T00:00:00","2018-02-13T00:00:00","2018-02-14T00:00:00","2018-02-15T00:00:00","2018-02-16T00:00:00","2018-02-20T00:00:00","2018-02-21T00:00:00","2018-02-22T00:00:00","2018-02-23T00:00:00","2018-02-26T00:00:00","2018-02-27T00:00:00","2018-02-28T00:00:00","2018-03-01T00:00:00","2018-03-02T00:00:00","2018-03-05T00:00:00","2018-03-06T00:00:00","2018-03-07T00:00:00","2018-03-08T00:00:00","2018-03-09T00:00:00","2018-03-12T00:00:00","2018-03-13T00:00:00","2018-03-14T00:00:00","2018-03-15T00:00:00","2018-03-16T00:00:00","2018-03-19T00:00:00","2018-03-20T00:00:00","2018-03-21T00:00:00","2018-03-22T00:00:00","2018-03-23T00:00:00","2018-03-26T00:00:00","2018-03-27T00:00:00","2018-03-28T00:00:00","2018-03-29T00:00:00","2018-04-02T00:00:00","2018-04-03T00:00:00","2018-04-04T00:00:00","2018-04-05T00:00:00","2018-04-06T00:00:00","2018-04-09T00:00:00","2018-04-10T00:00:00","2018-04-11T00:00:00","2018-04-12T00:00:00","2018-04-13T00:00:00","2018-04-16T00:00:00","2018-04-17T00:00:00","2018-04-18T00:00:00","2018-04-19T00:00:00","2018-04-20T00:00:00","2018-04-23T00:00:00","2018-04-24T00:00:00","2018-04-25T00:00:00","2018-04-26T00:00:00","2018-04-27T00:00:00","2018-04-30T00:00:00","2018-05-01T00:00:00","2018-05-02T00:00:00","2018-05-03T00:00:00","2018-05-04T00:00:00","2018-05-07T00:00:00","2018-05-08T00:00:00","2018-05-09T00:00:00","2018-05-10T00:00:00","2018-05-11T00:00:00","2018-05-14T00:00:00","2018-05-15T00:00:00","2018-05-16T00:00:00","2018-05-17T00:00:00","2018-05-18T00:00:00","2018-05-21T00:00:00","2018-05-22T00:00:00","2018-05-23T00:00:00","2018-05-24T00:00:00","2018-05-25T00:00:00","2018-05-29T00:00:00","2018-05-30T00:00:00","2018-05-31T00:00:00","2018-06-01T00:00:00","2018-06-04T00:00:00","2018-06-05T00:00:00","2018-06-06T00:00:00","2018-06-07T00:00:00","2018-06-08T00:00:00","2018-06-11T00:00:00","2018-06-12T00:00:00","2018-06-13T00:00:00","2018-06-14T00:00:00","2018-06-15T00:00:00","2018-06-18T00:00:00","2018-06-19T00:00:00","2018-06-20T00:00:00","2018-06-21T00:00:00","2018-06-22T00:00:00","2018-06-25T00:00:00","2018-06-26T00:00:00","2018-06-27T00:00:00","2018-06-28T00:00:00","2018-06-29T00:00:00","2018-07-02T00:00:00","2018-07-03T00:00:00","2018-07-05T00:00:00","2018-07-06T00:00:00","2018-07-09T00:00:00","2018-07-10T00:00:00","2018-07-11T00:00:00","2018-07-12T00:00:00","2018-07-13T00:00:00","2018-07-16T00:00:00","2018-07-17T00:00:00","2018-07-18T00:00:00","2018-07-19T00:00:00","2018-07-20T00:00:00","2018-07-23T00:00:00","2018-07-24T00:00:00","2018-07-25T00:00:00","2018-07-26T00:00:00","2018-07-27T00:00:00","2018-07-30T00:00:00","2018-07-31T00:00:00","2018-08-01T00:00:00","2018-08-02T00:00:00","2018-08-03T00:00:00","2018-08-06T00:00:00","2018-08-07T00:00:00","2018-08-08T00:00:00","2018-08-09T00:00:00","2018-08-10T00:00:00","2018-08-13T00:00:00","2018-08-14T00:00:00","2 ...
# Epoch 1/25
# 45/45 [==============================] - 1s 6ms/step - loss: 0.1387 - val_loss: 0.3573
# Epoch 2/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0667 - val_loss: 0.3584
# Epoch 3/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0556 - val_loss: 0.2855
# Epoch 4/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0543 - val_loss: 0.2821
# Epoch 5/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0485 - val_loss: 0.3366
# Epoch 6/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0441 - val_loss: 0.2410
# Epoch 7/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0436 - val_loss: 0.2662
# Epoch 8/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0399 - val_loss: 0.1721
# Epoch 9/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0311 - val_loss: 0.0834
# Epoch 10/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0203 - val_loss: 0.0647
# Epoch 11/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0151 - val_loss: 0.0323
# Epoch 12/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0124 - val_loss: 0.0272
# Epoch 13/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0117 - val_loss: 0.0177
# Epoch 14/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0105 - val_loss: 0.0172
# Epoch 15/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0095 - val_loss: 0.0108
# Epoch 16/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0086 - val_loss: 0.0062
# Epoch 17/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0099 - val_loss: 0.0114
# Epoch 18/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0090 - val_loss: 0.0092
# Epoch 19/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0071 - val_loss: 0.0033
# Epoch 20/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0092 - val_loss: 0.0029
# Epoch 21/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0066 - val_loss: 0.0045
# Epoch 22/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0071 - val_loss: 0.0018
# Epoch 23/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0062 - val_loss: 0.0063
# Epoch 24/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0064 - val_loss: 0.0039
# Epoch 25/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0059 - val_loss: 0.0039
#                Close
# Date
# 2021-07-09  0.675419
# 2021-07-12  0.686554
# 2021-07-13  0.684763
# 2021-07-14  0.693138
# 2021-07-15  0.714209
# ...              ...
# 2022-05-16  0.722599
# 2022-05-17  0.707075
# 2022-05-18  0.714729
# 2022-05-19  0.677891
# 2022-05-20  0.654101
#
# [220 rows x 1 columns]
#
# Head of "inv_yhat":
#  [[134.4710129 ]
#  [136.10187015]
#  [135.8395645 ]
#  [137.06616009]
#  [140.15234359]]
#
# Head of "inv_testy":
#  [[145.11000061]
#  [144.5       ]
#  [145.63999939]
#  [149.1499939 ]
#  [148.47999573]]
# 1
# <div>                            <div id="0571fabc-083b-4cdf-9a08-60347110a38f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0571fabc-083b-4cdf-9a08-60347110a38f")) {                    Plotly.newPlot(                        "0571fabc-083b-4cdf-9a08-60347110a38f",                        [{"mode":"lines","name":"Data","x":["2018-01-02T00:00:00","2018-01-03T00:00:00","2018-01-04T00:00:00","2018-01-05T00:00:00","2018-01-08T00:00:00","2018-01-09T00:00:00","2018-01-10T00:00:00","2018-01-11T00:00:00","2018-01-12T00:00:00","2018-01-16T00:00:00","2018-01-17T00:00:00","2018-01-18T00:00:00","2018-01-19T00:00:00","2018-01-22T00:00:00","2018-01-23T00:00:00","2018-01-24T00:00:00","2018-01-25T00:00:00","2018-01-26T00:00:00","2018-01-29T00:00:00","2018-01-30T00:00:00","2018-01-31T00:00:00","2018-02-01T00:00:00","2018-02-02T00:00:00","2018-02-05T00:00:00","2018-02-06T00:00:00","2018-02-07T00:00:00","2018-02-08T00:00:00","2018-02-09T00:00:00","2018-02-12T00:00:00","2018-02-13T00:00:00","2018-02-14T00:00:00","2018-02-15T00:00:00","2018-02-16T00:00:00","2018-02-20T00:00:00","2018-02-21T00:00:00","2018-02-22T00:00:00","2018-02-23T00:00:00","2018-02-26T00:00:00","2018-02-27T00:00:00","2018-02-28T00:00:00","2018-03-01T00:00:00","2018-03-02T00:00:00","2018-03-05T00:00:00","2018-03-06T00:00:00","2018-03-07T00:00:00","2018-03-08T00:00:00","2018-03-09T00:00:00","2018-03-12T00:00:00","2018-03-13T00:00:00","2018-03-14T00:00:00","2018-03-15T00:00:00","2018-03-16T00:00:00","2018-03-19T00:00:00","2018-03-20T00:00:00","2018-03-21T00:00:00","2018-03-22T00:00:00","2018-03-23T00:00:00","2018-03-26T00:00:00","2018-03-27T00:00:00","2018-03-28T00:00:00","2018-03-29T00:00:00","2018-04-02T00:00:00","2018-04-03T00:00:00","2018-04-04T00:00:00","2018-04-05T00:00:00","2018-04-06T00:00:00","2018-04-09T00:00:00","2018-04-10T00:00:00","2018-04-11T00:00:00","2018-04-12T00:00:00","2018-04-13T00:00:00","2018-04-16T00:00:00","2018-04-17T00:00:00","2018-04-18T00:00:00","2018-04-19T00:00:00","2018-04-20T00:00:00","2018-04-23T00:00:00","2018-04-24T00:00:00","2018-04-25T00:00:00","2018-04-26T00:00:00","2018-04-27T00:00:00","2018-04-30T00:00:00","2018-05-01T00:00:00","2018-05-02T00:00:00","2018-05-03T00:00:00","2018-05-04T00:00:00","2018-05-07T00:00:00","2018-05-08T00:00:00","2018-05-09T00:00:00","2018-05-10T00:00:00","2018-05-11T00:00:00","2018-05-14T00:00:00","2018-05-15T00:00:00","2018-05-16T00:00:00","2018-05-17T00:00:00","2018-05-18T00:00:00","2018-05-21T00:00:00","2018-05-22T00:00:00","2018-05-23T00:00:00","2018-05-24T00:00:00","2018-05-25T00:00:00","2018-05-29T00:00:00","2018-05-30T00:00:00","2018-05-31T00:00:00","2018-06-01T00:00:00","2018-06-04T00:00:00","2018-06-05T00:00:00","2018-06-06T00:00:00","2018-06-07T00:00:00","2018-06-08T00:00:00","2018-06-11T00:00:00","2018-06-12T00:00:00","2018-06-13T00:00:00","2018-06-14T00:00:00","2018-06-15T00:00:00","2018-06-18T00:00:00","2018-06-19T00:00:00","2018-06-20T00:00:00","2018-06-21T00:00:00","2018-06-22T00:00:00","2018-06-25T00:00:00","2018-06-26T00:00:00","2018-06-27T00:00:00","2018-06-28T00:00:00","2018-06-29T00:00:00","2018-07-02T00:00:00","2018-07-03T00:00:00","2018-07-05T00:00:00","2018-07-06T00:00:00","2018-07-09T00:00:00","2018-07-10T00:00:00","2018-07-11T00:00:00","2018-07-12T00:00:00","2018-07-13T00:00:00","2018-07-16T00:00:00","2018-07-17T00:00:00","2018-07-18T00:00:00","2018-07-19T00:00:00","2018-07-20T00:00:00","2018-07-23T00:00:00","2018-07-24T00:00:00","2018-07-25T00:00:00","2018-07-26T00:00:00","2018-07-27T00:00:00","2018-07-30T00:00:00","2018-07-31T00:00:00","2018-08-01T00:00:00","2018-08-02T00:00:00","2018-08-03T00:00:00","2018-08-06T00:00:00","2018-08-07T00:00:00","2018-08-08T00:00:00","2018-08-09T00:00:00","2018-08-10T00:00:00","2018-08-13T00:00:00","2018-08-14T00:00:00","2 ...
# Epoch 1/25
# 45/45 [==============================] - 1s 8ms/step - loss: 6.6895 - val_loss: 0.1798
# Epoch 2/25
# 45/45 [==============================] - 0s 2ms/step - loss: 2.1862 - val_loss: 0.2635
# Epoch 3/25
# 45/45 [==============================] - 0s 2ms/step - loss: 1.2331 - val_loss: 0.1662
# Epoch 4/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4658 - val_loss: 0.2736
# Epoch 5/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1788 - val_loss: 0.2644
# Epoch 6/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0911 - val_loss: 0.1749
# Epoch 7/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0704 - val_loss: 0.2047
# Epoch 8/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0579 - val_loss: 0.1856
# Epoch 9/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0409 - val_loss: 0.0838
# Epoch 10/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0273 - val_loss: 0.0723
# Epoch 11/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0180 - val_loss: 0.0378
# Epoch 12/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0162 - val_loss: 0.0397
# Epoch 13/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0157 - val_loss: 0.0309
# Epoch 14/25
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0140 - val_loss: 0.0259
# Epoch 15/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0129 - val_loss: 0.0185
# Epoch 16/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0115 - val_loss: 0.0150
# Epoch 17/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0114 - val_loss: 0.0156
# Epoch 18/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0111 - val_loss: 0.0113
# Epoch 19/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0119 - val_loss: 0.0095
# Epoch 20/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0099 - val_loss: 0.0079
# Epoch 21/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0097 - val_loss: 0.0091
# Epoch 22/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0087 - val_loss: 0.0090
# Epoch 23/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0088 - val_loss: 0.0062
# Epoch 24/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0076 - val_loss: 0.0145
# Epoch 25/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0081 - val_loss: 0.0046
#                Close
# Date
# 2021-07-09  0.717177
# 2021-07-12  0.725878
# 2021-07-13  0.728434
# 2021-07-14  0.738721
# 2021-07-15  0.754389
# ...              ...
# 2022-05-16  0.732176
# 2022-05-17  0.717445
# 2022-05-18  0.728956
# 2022-05-19  0.685531
# 2022-05-20  0.649224
#
# [220 rows x 1 columns]
#
# Head of "inv_yhat":
#  [[140.5870113 ]
#  [141.86144644]
#  [142.23574727]
#  [143.74244867]
#  [146.03719316]]
#
# Head of "inv_testy":
#  [[145.11000061]
#  [144.5       ]
#  [145.63999939]
#  [149.1499939 ]
#  [148.47999573]]
# 1
# <div>                            <div id="4cec8066-4824-4da8-88dd-156a443daa24" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4cec8066-4824-4da8-88dd-156a443daa24")) {                    Plotly.newPlot(                        "4cec8066-4824-4da8-88dd-156a443daa24",                        [{"mode":"lines","name":"Data","x":["2018-01-02T00:00:00","2018-01-03T00:00:00","2018-01-04T00:00:00","2018-01-05T00:00:00","2018-01-08T00:00:00","2018-01-09T00:00:00","2018-01-10T00:00:00","2018-01-11T00:00:00","2018-01-12T00:00:00","2018-01-16T00:00:00","2018-01-17T00:00:00","2018-01-18T00:00:00","2018-01-19T00:00:00","2018-01-22T00:00:00","2018-01-23T00:00:00","2018-01-24T00:00:00","2018-01-25T00:00:00","2018-01-26T00:00:00","2018-01-29T00:00:00","2018-01-30T00:00:00","2018-01-31T00:00:00","2018-02-01T00:00:00","2018-02-02T00:00:00","2018-02-05T00:00:00","2018-02-06T00:00:00","2018-02-07T00:00:00","2018-02-08T00:00:00","2018-02-09T00:00:00","2018-02-12T00:00:00","2018-02-13T00:00:00","2018-02-14T00:00:00","2018-02-15T00:00:00","2018-02-16T00:00:00","2018-02-20T00:00:00","2018-02-21T00:00:00","2018-02-22T00:00:00","2018-02-23T00:00:00","2018-02-26T00:00:00","2018-02-27T00:00:00","2018-02-28T00:00:00","2018-03-01T00:00:00","2018-03-02T00:00:00","2018-03-05T00:00:00","2018-03-06T00:00:00","2018-03-07T00:00:00","2018-03-08T00:00:00","2018-03-09T00:00:00","2018-03-12T00:00:00","2018-03-13T00:00:00","2018-03-14T00:00:00","2018-03-15T00:00:00","2018-03-16T00:00:00","2018-03-19T00:00:00","2018-03-20T00:00:00","2018-03-21T00:00:00","2018-03-22T00:00:00","2018-03-23T00:00:00","2018-03-26T00:00:00","2018-03-27T00:00:00","2018-03-28T00:00:00","2018-03-29T00:00:00","2018-04-02T00:00:00","2018-04-03T00:00:00","2018-04-04T00:00:00","2018-04-05T00:00:00","2018-04-06T00:00:00","2018-04-09T00:00:00","2018-04-10T00:00:00","2018-04-11T00:00:00","2018-04-12T00:00:00","2018-04-13T00:00:00","2018-04-16T00:00:00","2018-04-17T00:00:00","2018-04-18T00:00:00","2018-04-19T00:00:00","2018-04-20T00:00:00","2018-04-23T00:00:00","2018-04-24T00:00:00","2018-04-25T00:00:00","2018-04-26T00:00:00","2018-04-27T00:00:00","2018-04-30T00:00:00","2018-05-01T00:00:00","2018-05-02T00:00:00","2018-05-03T00:00:00","2018-05-04T00:00:00","2018-05-07T00:00:00","2018-05-08T00:00:00","2018-05-09T00:00:00","2018-05-10T00:00:00","2018-05-11T00:00:00","2018-05-14T00:00:00","2018-05-15T00:00:00","2018-05-16T00:00:00","2018-05-17T00:00:00","2018-05-18T00:00:00","2018-05-21T00:00:00","2018-05-22T00:00:00","2018-05-23T00:00:00","2018-05-24T00:00:00","2018-05-25T00:00:00","2018-05-29T00:00:00","2018-05-30T00:00:00","2018-05-31T00:00:00","2018-06-01T00:00:00","2018-06-04T00:00:00","2018-06-05T00:00:00","2018-06-06T00:00:00","2018-06-07T00:00:00","2018-06-08T00:00:00","2018-06-11T00:00:00","2018-06-12T00:00:00","2018-06-13T00:00:00","2018-06-14T00:00:00","2018-06-15T00:00:00","2018-06-18T00:00:00","2018-06-19T00:00:00","2018-06-20T00:00:00","2018-06-21T00:00:00","2018-06-22T00:00:00","2018-06-25T00:00:00","2018-06-26T00:00:00","2018-06-27T00:00:00","2018-06-28T00:00:00","2018-06-29T00:00:00","2018-07-02T00:00:00","2018-07-03T00:00:00","2018-07-05T00:00:00","2018-07-06T00:00:00","2018-07-09T00:00:00","2018-07-10T00:00:00","2018-07-11T00:00:00","2018-07-12T00:00:00","2018-07-13T00:00:00","2018-07-16T00:00:00","2018-07-17T00:00:00","2018-07-18T00:00:00","2018-07-19T00:00:00","2018-07-20T00:00:00","2018-07-23T00:00:00","2018-07-24T00:00:00","2018-07-25T00:00:00","2018-07-26T00:00:00","2018-07-27T00:00:00","2018-07-30T00:00:00","2018-07-31T00:00:00","2018-08-01T00:00:00","2018-08-02T00:00:00","2018-08-03T00:00:00","2018-08-06T00:00:00","2018-08-07T00:00:00","2018-08-08T00:00:00","2018-08-09T00:00:00","2018-08-10T00:00:00","2018-08-13T00:00:00","2018-08-14T00:00:00","2 ...
# Epoch 1/25
# 45/45 [==============================] - 2s 13ms/step - loss: 0.3416 - val_loss: 0.4994
# Epoch 2/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.1283 - val_loss: 0.4086
# Epoch 3/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0594 - val_loss: 0.2951
# Epoch 4/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0495 - val_loss: 0.2835
# Epoch 5/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0472 - val_loss: 0.2723
# Epoch 6/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0442 - val_loss: 0.2049
# Epoch 7/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0356 - val_loss: 0.1850
# Epoch 8/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0265 - val_loss: 0.0943
# Epoch 9/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0183 - val_loss: 0.0780
# Epoch 10/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0137 - val_loss: 0.0356
# Epoch 11/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0102 - val_loss: 0.0232
# Epoch 12/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0088 - val_loss: 0.0195
# Epoch 13/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0081 - val_loss: 0.0118
# Epoch 14/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0098 - val_loss: 0.0110
# Epoch 15/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0075 - val_loss: 0.0105
# Epoch 16/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0071 - val_loss: 0.0065
# Epoch 17/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0072 - val_loss: 0.0128
# Epoch 18/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0074 - val_loss: 0.0073
# Epoch 19/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0046
# Epoch 20/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0069 - val_loss: 0.0050
# Epoch 21/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0064 - val_loss: 0.0041
# Epoch 22/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0065 - val_loss: 0.0033
# Epoch 23/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0057 - val_loss: 0.0022
# Epoch 24/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0020
# Epoch 25/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0053 - val_loss: 0.0022
#                Close
# Date
# 2021-07-09  0.695760
# 2021-07-12  0.706619
# 2021-07-13  0.706792
# 2021-07-14  0.717012
# 2021-07-15  0.736587
# ...              ...
# 2022-05-16  0.743971
# 2022-05-17  0.727815
# 2022-05-18  0.748802
# 2022-05-19  0.696678
# 2022-05-20  0.693182
#
# [220 rows x 1 columns]
#
# Head of "inv_yhat":
#  [[137.45026453]
#  [139.04064149]
#  [139.06596677]
#  [140.56283836]
#  [143.42987657]]
#
# Head of "inv_testy":
#  [[145.11000061]
#  [144.5       ]
#  [145.63999939]
#  [149.1499939 ]
#  [148.47999573]]
# 1
# <div>                            <div id="5da32965-8050-4a0c-a877-9187f177e1e7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5da32965-8050-4a0c-a877-9187f177e1e7")) {                    Plotly.newPlot(                        "5da32965-8050-4a0c-a877-9187f177e1e7",                        [{"mode":"lines","name":"Data","x":["2018-01-02T00:00:00","2018-01-03T00:00:00","2018-01-04T00:00:00","2018-01-05T00:00:00","2018-01-08T00:00:00","2018-01-09T00:00:00","2018-01-10T00:00:00","2018-01-11T00:00:00","2018-01-12T00:00:00","2018-01-16T00:00:00","2018-01-17T00:00:00","2018-01-18T00:00:00","2018-01-19T00:00:00","2018-01-22T00:00:00","2018-01-23T00:00:00","2018-01-24T00:00:00","2018-01-25T00:00:00","2018-01-26T00:00:00","2018-01-29T00:00:00","2018-01-30T00:00:00","2018-01-31T00:00:00","2018-02-01T00:00:00","2018-02-02T00:00:00","2018-02-05T00:00:00","2018-02-06T00:00:00","2018-02-07T00:00:00","2018-02-08T00:00:00","2018-02-09T00:00:00","2018-02-12T00:00:00","2018-02-13T00:00:00","2018-02-14T00:00:00","2018-02-15T00:00:00","2018-02-16T00:00:00","2018-02-20T00:00:00","2018-02-21T00:00:00","2018-02-22T00:00:00","2018-02-23T00:00:00","2018-02-26T00:00:00","2018-02-27T00:00:00","2018-02-28T00:00:00","2018-03-01T00:00:00","2018-03-02T00:00:00","2018-03-05T00:00:00","2018-03-06T00:00:00","2018-03-07T00:00:00","2018-03-08T00:00:00","2018-03-09T00:00:00","2018-03-12T00:00:00","2018-03-13T00:00:00","2018-03-14T00:00:00","2018-03-15T00:00:00","2018-03-16T00:00:00","2018-03-19T00:00:00","2018-03-20T00:00:00","2018-03-21T00:00:00","2018-03-22T00:00:00","2018-03-23T00:00:00","2018-03-26T00:00:00","2018-03-27T00:00:00","2018-03-28T00:00:00","2018-03-29T00:00:00","2018-04-02T00:00:00","2018-04-03T00:00:00","2018-04-04T00:00:00","2018-04-05T00:00:00","2018-04-06T00:00:00","2018-04-09T00:00:00","2018-04-10T00:00:00","2018-04-11T00:00:00","2018-04-12T00:00:00","2018-04-13T00:00:00","2018-04-16T00:00:00","2018-04-17T00:00:00","2018-04-18T00:00:00","2018-04-19T00:00:00","2018-04-20T00:00:00","2018-04-23T00:00:00","2018-04-24T00:00:00","2018-04-25T00:00:00","2018-04-26T00:00:00","2018-04-27T00:00:00","2018-04-30T00:00:00","2018-05-01T00:00:00","2018-05-02T00:00:00","2018-05-03T00:00:00","2018-05-04T00:00:00","2018-05-07T00:00:00","2018-05-08T00:00:00","2018-05-09T00:00:00","2018-05-10T00:00:00","2018-05-11T00:00:00","2018-05-14T00:00:00","2018-05-15T00:00:00","2018-05-16T00:00:00","2018-05-17T00:00:00","2018-05-18T00:00:00","2018-05-21T00:00:00","2018-05-22T00:00:00","2018-05-23T00:00:00","2018-05-24T00:00:00","2018-05-25T00:00:00","2018-05-29T00:00:00","2018-05-30T00:00:00","2018-05-31T00:00:00","2018-06-01T00:00:00","2018-06-04T00:00:00","2018-06-05T00:00:00","2018-06-06T00:00:00","2018-06-07T00:00:00","2018-06-08T00:00:00","2018-06-11T00:00:00","2018-06-12T00:00:00","2018-06-13T00:00:00","2018-06-14T00:00:00","2018-06-15T00:00:00","2018-06-18T00:00:00","2018-06-19T00:00:00","2018-06-20T00:00:00","2018-06-21T00:00:00","2018-06-22T00:00:00","2018-06-25T00:00:00","2018-06-26T00:00:00","2018-06-27T00:00:00","2018-06-28T00:00:00","2018-06-29T00:00:00","2018-07-02T00:00:00","2018-07-03T00:00:00","2018-07-05T00:00:00","2018-07-06T00:00:00","2018-07-09T00:00:00","2018-07-10T00:00:00","2018-07-11T00:00:00","2018-07-12T00:00:00","2018-07-13T00:00:00","2018-07-16T00:00:00","2018-07-17T00:00:00","2018-07-18T00:00:00","2018-07-19T00:00:00","2018-07-20T00:00:00","2018-07-23T00:00:00","2018-07-24T00:00:00","2018-07-25T00:00:00","2018-07-26T00:00:00","2018-07-27T00:00:00","2018-07-30T00:00:00","2018-07-31T00:00:00","2018-08-01T00:00:00","2018-08-02T00:00:00","2018-08-03T00:00:00","2018-08-06T00:00:00","2018-08-07T00:00:00","2018-08-08T00:00:00","2018-08-09T00:00:00","2018-08-10T00:00:00","2018-08-13T00:00:00","2018-08-14T00:00:00","2 ...
# Epoch 1/25
# 45/45 [==============================] - 2s 11ms/step - loss: 0.4481 - val_loss: 0.3733
# Epoch 2/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.1331 - val_loss: 0.3086
# Epoch 3/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0719 - val_loss: 0.2988
# Epoch 4/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0591 - val_loss: 0.2455
# Epoch 5/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0491 - val_loss: 0.2583
# Epoch 6/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0427 - val_loss: 0.2257
# Epoch 7/25
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0401 - val_loss: 0.1989
# Epoch 8/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0359 - val_loss: 0.2131
# Epoch 9/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0350 - val_loss: 0.1793
# Epoch 10/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0334 - val_loss: 0.1415
# Epoch 11/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0262 - val_loss: 0.0939
# Epoch 12/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0229 - val_loss: 0.0826
# Epoch 13/25
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0178 - val_loss: 0.0743
# Epoch 14/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0151 - val_loss: 0.0444
# Epoch 15/25
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0133 - val_loss: 0.0218
# Epoch 16/25
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0106 - val_loss: 0.0149
# Epoch 17/25
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0083 - val_loss: 0.0095
# Epoch 18/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0067 - val_loss: 0.0101
# Epoch 19/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 0.0085
# Epoch 20/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0065 - val_loss: 0.0061
# Epoch 21/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0055 - val_loss: 0.0049
# Epoch 22/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0045 - val_loss: 0.0056
# Epoch 23/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0052 - val_loss: 0.0025
# Epoch 24/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0055 - val_loss: 0.0039
# Epoch 25/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0027
#                Close
# Date
# 2021-07-09  0.696559
# 2021-07-12  0.706368
# 2021-07-13  0.707700
# 2021-07-14  0.718249
# 2021-07-15  0.735275
# ...              ...
# 2022-05-16  0.775845
# 2022-05-17  0.753264
# 2022-05-18  0.761927
# 2022-05-19  0.723878
# 2022-05-20  0.669643
#
# [220 rows x 1 columns]
#
# Head of "inv_yhat":
#  [[137.56727937]
#  [139.00388884]
#  [139.1990358 ]
#  [140.74411359]
#  [143.23768903]]
#
# Head of "inv_testy":
#  [[145.11000061]
#  [144.5       ]
#  [145.63999939]
#  [149.1499939 ]
#  [148.47999573]]
# 1
# <div>                            <div id="11981829-c833-4b09-8ed5-05820f37caef" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("11981829-c833-4b09-8ed5-05820f37caef")) {                    Plotly.newPlot(                        "11981829-c833-4b09-8ed5-05820f37caef",                        [{"mode":"lines","name":"Data","x":["2018-01-02T00:00:00","2018-01-03T00:00:00","2018-01-04T00:00:00","2018-01-05T00:00:00","2018-01-08T00:00:00","2018-01-09T00:00:00","2018-01-10T00:00:00","2018-01-11T00:00:00","2018-01-12T00:00:00","2018-01-16T00:00:00","2018-01-17T00:00:00","2018-01-18T00:00:00","2018-01-19T00:00:00","2018-01-22T00:00:00","2018-01-23T00:00:00","2018-01-24T00:00:00","2018-01-25T00:00:00","2018-01-26T00:00:00","2018-01-29T00:00:00","2018-01-30T00:00:00","2018-01-31T00:00:00","2018-02-01T00:00:00","2018-02-02T00:00:00","2018-02-05T00:00:00","2018-02-06T00:00:00","2018-02-07T00:00:00","2018-02-08T00:00:00","2018-02-09T00:00:00","2018-02-12T00:00:00","2018-02-13T00:00:00","2018-02-14T00:00:00","2018-02-15T00:00:00","2018-02-16T00:00:00","2018-02-20T00:00:00","2018-02-21T00:00:00","2018-02-22T00:00:00","2018-02-23T00:00:00","2018-02-26T00:00:00","2018-02-27T00:00:00","2018-02-28T00:00:00","2018-03-01T00:00:00","2018-03-02T00:00:00","2018-03-05T00:00:00","2018-03-06T00:00:00","2018-03-07T00:00:00","2018-03-08T00:00:00","2018-03-09T00:00:00","2018-03-12T00:00:00","2018-03-13T00:00:00","2018-03-14T00:00:00","2018-03-15T00:00:00","2018-03-16T00:00:00","2018-03-19T00:00:00","2018-03-20T00:00:00","2018-03-21T00:00:00","2018-03-22T00:00:00","2018-03-23T00:00:00","2018-03-26T00:00:00","2018-03-27T00:00:00","2018-03-28T00:00:00","2018-03-29T00:00:00","2018-04-02T00:00:00","2018-04-03T00:00:00","2018-04-04T00:00:00","2018-04-05T00:00:00","2018-04-06T00:00:00","2018-04-09T00:00:00","2018-04-10T00:00:00","2018-04-11T00:00:00","2018-04-12T00:00:00","2018-04-13T00:00:00","2018-04-16T00:00:00","2018-04-17T00:00:00","2018-04-18T00:00:00","2018-04-19T00:00:00","2018-04-20T00:00:00","2018-04-23T00:00:00","2018-04-24T00:00:00","2018-04-25T00:00:00","2018-04-26T00:00:00","2018-04-27T00:00:00","2018-04-30T00:00:00","2018-05-01T00:00:00","2018-05-02T00:00:00","2018-05-03T00:00:00","2018-05-04T00:00:00","2018-05-07T00:00:00","2018-05-08T00:00:00","2018-05-09T00:00:00","2018-05-10T00:00:00","2018-05-11T00:00:00","2018-05-14T00:00:00","2018-05-15T00:00:00","2018-05-16T00:00:00","2018-05-17T00:00:00","2018-05-18T00:00:00","2018-05-21T00:00:00","2018-05-22T00:00:00","2018-05-23T00:00:00","2018-05-24T00:00:00","2018-05-25T00:00:00","2018-05-29T00:00:00","2018-05-30T00:00:00","2018-05-31T00:00:00","2018-06-01T00:00:00","2018-06-04T00:00:00","2018-06-05T00:00:00","2018-06-06T00:00:00","2018-06-07T00:00:00","2018-06-08T00:00:00","2018-06-11T00:00:00","2018-06-12T00:00:00","2018-06-13T00:00:00","2018-06-14T00:00:00","2018-06-15T00:00:00","2018-06-18T00:00:00","2018-06-19T00:00:00","2018-06-20T00:00:00","2018-06-21T00:00:00","2018-06-22T00:00:00","2018-06-25T00:00:00","2018-06-26T00:00:00","2018-06-27T00:00:00","2018-06-28T00:00:00","2018-06-29T00:00:00","2018-07-02T00:00:00","2018-07-03T00:00:00","2018-07-05T00:00:00","2018-07-06T00:00:00","2018-07-09T00:00:00","2018-07-10T00:00:00","2018-07-11T00:00:00","2018-07-12T00:00:00","2018-07-13T00:00:00","2018-07-16T00:00:00","2018-07-17T00:00:00","2018-07-18T00:00:00","2018-07-19T00:00:00","2018-07-20T00:00:00","2018-07-23T00:00:00","2018-07-24T00:00:00","2018-07-25T00:00:00","2018-07-26T00:00:00","2018-07-27T00:00:00","2018-07-30T00:00:00","2018-07-31T00:00:00","2018-08-01T00:00:00","2018-08-02T00:00:00","2018-08-03T00:00:00","2018-08-06T00:00:00","2018-08-07T00:00:00","2018-08-08T00:00:00","2018-08-09T00:00:00","2018-08-10T00:00:00","2018-08-13T00:00:00","2018-08-14T00:00:00","2 ...
# Epoch 1/25
# 45/45 [==============================] - 1s 7ms/step - loss: 2.2934 - val_loss: 0.2588
# Epoch 2/25
# 45/45 [==============================] - 0s 2ms/step - loss: 1.0655 - val_loss: 0.2556
# Epoch 3/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4096 - val_loss: 0.2609
# Epoch 4/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.2029 - val_loss: 0.1709
# Epoch 5/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1053 - val_loss: 0.2292
# Epoch 6/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0580 - val_loss: 0.2046
# Epoch 7/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0461 - val_loss: 0.1828
# Epoch 8/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0387 - val_loss: 0.1395
# Epoch 9/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0349 - val_loss: 0.1346
# Epoch 10/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0293 - val_loss: 0.0821
# Epoch 11/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0251 - val_loss: 0.0594
# Epoch 12/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0232 - val_loss: 0.0371
# Epoch 13/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0186 - val_loss: 0.0447
# Epoch 14/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0176 - val_loss: 0.0388
# Epoch 15/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0169 - val_loss: 0.0269
# Epoch 16/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0117 - val_loss: 0.0211
# Epoch 17/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0114 - val_loss: 0.0146
# Epoch 18/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0121 - val_loss: 0.0174
# Epoch 19/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0103 - val_loss: 0.0075
# Epoch 20/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0110 - val_loss: 0.0085
# Epoch 21/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0107 - val_loss: 0.0068
# Epoch 22/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0096 - val_loss: 0.0090
# Epoch 23/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0093 - val_loss: 0.0174
# Epoch 24/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0091 - val_loss: 0.0066
# Epoch 25/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0084 - val_loss: 0.0075
#                Close
# Date
# 2021-07-09  0.646314
# 2021-07-12  0.652896
# 2021-07-13  0.659534
# 2021-07-14  0.672324
# 2021-07-15  0.682007
# ...              ...
# 2022-05-16  0.741543
# 2022-05-17  0.725303
# 2022-05-18  0.740410
# 2022-05-19  0.693831
# 2022-05-20  0.649148
#
# [220 rows x 1 columns]
#
# Head of "inv_yhat":
#  [[130.20820343]
#  [131.17225767]
#  [132.14442193]
#  [134.01775935]
#  [135.43593139]]
#
# Head of "inv_testy":
#  [[145.11000061]
#  [144.5       ]
#  [145.63999939]
#  [149.1499939 ]
#  [148.47999573]]
# 1
# <div>                            <div id="878852d4-6e37-4052-ac64-0a8f5a87fe21" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("878852d4-6e37-4052-ac64-0a8f5a87fe21")) {                    Plotly.newPlot(                        "878852d4-6e37-4052-ac64-0a8f5a87fe21",                        [{"mode":"lines","name":"Data","x":["2018-01-02T00:00:00","2018-01-03T00:00:00","2018-01-04T00:00:00","2018-01-05T00:00:00","2018-01-08T00:00:00","2018-01-09T00:00:00","2018-01-10T00:00:00","2018-01-11T00:00:00","2018-01-12T00:00:00","2018-01-16T00:00:00","2018-01-17T00:00:00","2018-01-18T00:00:00","2018-01-19T00:00:00","2018-01-22T00:00:00","2018-01-23T00:00:00","2018-01-24T00:00:00","2018-01-25T00:00:00","2018-01-26T00:00:00","2018-01-29T00:00:00","2018-01-30T00:00:00","2018-01-31T00:00:00","2018-02-01T00:00:00","2018-02-02T00:00:00","2018-02-05T00:00:00","2018-02-06T00:00:00","2018-02-07T00:00:00","2018-02-08T00:00:00","2018-02-09T00:00:00","2018-02-12T00:00:00","2018-02-13T00:00:00","2018-02-14T00:00:00","2018-02-15T00:00:00","2018-02-16T00:00:00","2018-02-20T00:00:00","2018-02-21T00:00:00","2018-02-22T00:00:00","2018-02-23T00:00:00","2018-02-26T00:00:00","2018-02-27T00:00:00","2018-02-28T00:00:00","2018-03-01T00:00:00","2018-03-02T00:00:00","2018-03-05T00:00:00","2018-03-06T00:00:00","2018-03-07T00:00:00","2018-03-08T00:00:00","2018-03-09T00:00:00","2018-03-12T00:00:00","2018-03-13T00:00:00","2018-03-14T00:00:00","2018-03-15T00:00:00","2018-03-16T00:00:00","2018-03-19T00:00:00","2018-03-20T00:00:00","2018-03-21T00:00:00","2018-03-22T00:00:00","2018-03-23T00:00:00","2018-03-26T00:00:00","2018-03-27T00:00:00","2018-03-28T00:00:00","2018-03-29T00:00:00","2018-04-02T00:00:00","2018-04-03T00:00:00","2018-04-04T00:00:00","2018-04-05T00:00:00","2018-04-06T00:00:00","2018-04-09T00:00:00","2018-04-10T00:00:00","2018-04-11T00:00:00","2018-04-12T00:00:00","2018-04-13T00:00:00","2018-04-16T00:00:00","2018-04-17T00:00:00","2018-04-18T00:00:00","2018-04-19T00:00:00","2018-04-20T00:00:00","2018-04-23T00:00:00","2018-04-24T00:00:00","2018-04-25T00:00:00","2018-04-26T00:00:00","2018-04-27T00:00:00","2018-04-30T00:00:00","2018-05-01T00:00:00","2018-05-02T00:00:00","2018-05-03T00:00:00","2018-05-04T00:00:00","2018-05-07T00:00:00","2018-05-08T00:00:00","2018-05-09T00:00:00","2018-05-10T00:00:00","2018-05-11T00:00:00","2018-05-14T00:00:00","2018-05-15T00:00:00","2018-05-16T00:00:00","2018-05-17T00:00:00","2018-05-18T00:00:00","2018-05-21T00:00:00","2018-05-22T00:00:00","2018-05-23T00:00:00","2018-05-24T00:00:00","2018-05-25T00:00:00","2018-05-29T00:00:00","2018-05-30T00:00:00","2018-05-31T00:00:00","2018-06-01T00:00:00","2018-06-04T00:00:00","2018-06-05T00:00:00","2018-06-06T00:00:00","2018-06-07T00:00:00","2018-06-08T00:00:00","2018-06-11T00:00:00","2018-06-12T00:00:00","2018-06-13T00:00:00","2018-06-14T00:00:00","2018-06-15T00:00:00","2018-06-18T00:00:00","2018-06-19T00:00:00","2018-06-20T00:00:00","2018-06-21T00:00:00","2018-06-22T00:00:00","2018-06-25T00:00:00","2018-06-26T00:00:00","2018-06-27T00:00:00","2018-06-28T00:00:00","2018-06-29T00:00:00","2018-07-02T00:00:00","2018-07-03T00:00:00","2018-07-05T00:00:00","2018-07-06T00:00:00","2018-07-09T00:00:00","2018-07-10T00:00:00","2018-07-11T00:00:00","2018-07-12T00:00:00","2018-07-13T00:00:00","2018-07-16T00:00:00","2018-07-17T00:00:00","2018-07-18T00:00:00","2018-07-19T00:00:00","2018-07-20T00:00:00","2018-07-23T00:00:00","2018-07-24T00:00:00","2018-07-25T00:00:00","2018-07-26T00:00:00","2018-07-27T00:00:00","2018-07-30T00:00:00","2018-07-31T00:00:00","2018-08-01T00:00:00","2018-08-02T00:00:00","2018-08-03T00:00:00","2018-08-06T00:00:00","2018-08-07T00:00:00","2018-08-08T00:00:00","2018-08-09T00:00:00","2018-08-10T00:00:00","2018-08-13T00:00:00","2018-08-14T00:00:00","2 ...
# Epoch 1/25
# 45/45 [==============================] - 2s 16ms/step - loss: 1.8908 - val_loss: 0.4647
# Epoch 2/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.7433 - val_loss: 0.2862
# Epoch 3/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1184 - val_loss: 0.2845
# Epoch 4/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0664 - val_loss: 0.2063
# Epoch 5/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0503 - val_loss: 0.1786
# Epoch 6/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0376 - val_loss: 0.1827
# Epoch 7/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0324 - val_loss: 0.1081
# Epoch 8/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0250 - val_loss: 0.0913
# Epoch 9/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0220 - val_loss: 0.0580
# Epoch 10/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0185 - val_loss: 0.0538
# Epoch 11/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0158 - val_loss: 0.0525
# Epoch 12/25
# 45/45 [==============================] - 0s 6ms/step - loss: 0.0131 - val_loss: 0.0379
# Epoch 13/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0114 - val_loss: 0.0181
# Epoch 14/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0088 - val_loss: 0.0204
# Epoch 15/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0103 - val_loss: 0.0128
# Epoch 16/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0079 - val_loss: 0.0120
# Epoch 17/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0096 - val_loss: 0.0126
# Epoch 18/25
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0079 - val_loss: 0.0081
# Epoch 19/25
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0082 - val_loss: 0.0089
# Epoch 20/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0074 - val_loss: 0.0061
# Epoch 21/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0070 - val_loss: 0.0068
# Epoch 22/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0066 - val_loss: 0.0075
# Epoch 23/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0060 - val_loss: 0.0050
# Epoch 24/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0051
# Epoch 25/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0058 - val_loss: 0.0064
#                Close
# Date
# 2021-07-09  0.660916
# 2021-07-12  0.668970
# 2021-07-13  0.674544
# 2021-07-14  0.687429
# 2021-07-15  0.700707
# ...              ...
# 2022-05-16  0.712258
# 2022-05-17  0.697872
# 2022-05-18  0.730155
# 2022-05-19  0.666581
# 2022-05-20  0.646469
#
# [220 rows x 1 columns]
#
# Head of "inv_yhat":
#  [[132.34686703]
#  [133.52644368]
#  [134.34290242]
#  [136.23008538]
#  [138.17485912]]
#
# Head of "inv_testy":
#  [[145.11000061]
#  [144.5       ]
#  [145.63999939]
#  [149.1499939 ]
#  [148.47999573]]
# 1
# ...
# Epoch 1/25
# 45/45 [==============================] - 2s 11ms/step - loss: 12.2144 - val_loss: 0.7237
# Epoch 2/25
# 45/45 [==============================] - 0s 3ms/step - loss: 2.5131 - val_loss: 0.6956
# Epoch 3/25
# 45/45 [==============================] - 0s 5ms/step - loss: 1.1175 - val_loss: 0.3578
# Epoch 4/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.5846 - val_loss: 0.2457
# Epoch 5/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.3698 - val_loss: 0.2359
# Epoch 6/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1603 - val_loss: 0.2083
# Epoch 7/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0924 - val_loss: 0.2406
# Epoch 8/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0782 - val_loss: 0.2152
# Epoch 9/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0609 - val_loss: 0.1506
# Epoch 10/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0525 - val_loss: 0.1349
# Epoch 11/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0394 - val_loss: 0.0709
# Epoch 12/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0314 - val_loss: 0.0536
# Epoch 13/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0253 - val_loss: 0.0183
# Epoch 14/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0234 - val_loss: 0.0262
# Epoch 15/25
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0196 - val_loss: 0.0227
# Epoch 16/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0167 - val_loss: 0.0140
# Epoch 17/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0147 - val_loss: 0.0078
# Epoch 18/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0130 - val_loss: 0.0116
# Epoch 19/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0106 - val_loss: 0.0136
# Epoch 20/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0113 - val_loss: 0.0051
# Epoch 21/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0096 - val_loss: 0.0071
# Epoch 22/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0101 - val_loss: 0.0041
# Epoch 23/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0092 - val_loss: 0.0066
# Epoch 24/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0085 - val_loss: 0.0100
# Epoch 25/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0100 - val_loss: 0.0028
#                Close
# Date
# 2021-07-09  0.724298
# 2021-07-12  0.733972
# 2021-07-13  0.736217
# 2021-07-14  0.747615
# 2021-07-15  0.763942
# ...              ...
# 2022-05-16  0.768855
# 2022-05-17  0.753547
# 2022-05-18  0.788413
# 2022-05-19  0.720259
# 2022-05-20  0.693122
#
# [220 rows x 1 columns]
#
# Head of "inv_yhat":
#  [[141.63005317]
#  [143.04692446]
#  [143.37571661]
#  [145.04508121]
#  [147.43633414]]
#
# Head of "inv_testy":
#  [[145.11000061]
#  [144.5       ]
#  [145.63999939]
#  [149.1499939 ]
#  [148.47999573]]
# 1
# <div>                            <div id="25e1fddc-0589-43c8-93ff-3312d572c5d3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("25e1fddc-0589-43c8-93ff-3312d572c5d3")) {                    Plotly.newPlot(                        "25e1fddc-0589-43c8-93ff-3312d572c5d3",                        [{"mode":"lines","name":"Data","x":["2018-01-02T00:00:00","2018-01-03T00:00:00","2018-01-04T00:00:00","2018-01-05T00:00:00","2018-01-08T00:00:00","2018-01-09T00:00:00","2018-01-10T00:00:00","2018-01-11T00:00:00","2018-01-12T00:00:00","2018-01-16T00:00:00","2018-01-17T00:00:00","2018-01-18T00:00:00","2018-01-19T00:00:00","2018-01-22T00:00:00","2018-01-23T00:00:00","2018-01-24T00:00:00","2018-01-25T00:00:00","2018-01-26T00:00:00","2018-01-29T00:00:00","2018-01-30T00:00:00","2018-01-31T00:00:00","2018-02-01T00:00:00","2018-02-02T00:00:00","2018-02-05T00:00:00","2018-02-06T00:00:00","2018-02-07T00:00:00","2018-02-08T00:00:00","2018-02-09T00:00:00","2018-02-12T00:00:00","2018-02-13T00:00:00","2018-02-14T00:00:00","2018-02-15T00:00:00","2018-02-16T00:00:00","2018-02-20T00:00:00","2018-02-21T00:00:00","2018-02-22T00:00:00","2018-02-23T00:00:00","2018-02-26T00:00:00","2018-02-27T00:00:00","2018-02-28T00:00:00","2018-03-01T00:00:00","2018-03-02T00:00:00","2018-03-05T00:00:00","2018-03-06T00:00:00","2018-03-07T00:00:00","2018-03-08T00:00:00","2018-03-09T00:00:00","2018-03-12T00:00:00","2018-03-13T00:00:00","2018-03-14T00:00:00","2018-03-15T00:00:00","2018-03-16T00:00:00","2018-03-19T00:00:00","2018-03-20T00:00:00","2018-03-21T00:00:00","2018-03-22T00:00:00","2018-03-23T00:00:00","2018-03-26T00:00:00","2018-03-27T00:00:00","2018-03-28T00:00:00","2018-03-29T00:00:00","2018-04-02T00:00:00","2018-04-03T00:00:00","2018-04-04T00:00:00","2018-04-05T00:00:00","2018-04-06T00:00:00","2018-04-09T00:00:00","2018-04-10T00:00:00","2018-04-11T00:00:00","2018-04-12T00:00:00","2018-04-13T00:00:00","2018-04-16T00:00:00","2018-04-17T00:00:00","2018-04-18T00:00:00","2018-04-19T00:00:00","2018-04-20T00:00:00","2018-04-23T00:00:00","2018-04-24T00:00:00","2018-04-25T00:00:00","2018-04-26T00:00:00","2018-04-27T00:00:00","2018-04-30T00:00:00","2018-05-01T00:00:00","2018-05-02T00:00:00","2018-05-03T00:00:00","2018-05-04T00:00:00","2018-05-07T00:00:00","2018-05-08T00:00:00","2018-05-09T00:00:00","2018-05-10T00:00:00","2018-05-11T00:00:00","2018-05-14T00:00:00","2018-05-15T00:00:00","2018-05-16T00:00:00","2018-05-17T00:00:00","2018-05-18T00:00:00","2018-05-21T00:00:00","2018-05-22T00:00:00","2018-05-23T00:00:00","2018-05-24T00:00:00","2018-05-25T00:00:00","2018-05-29T00:00:00","2018-05-30T00:00:00","2018-05-31T00:00:00","2018-06-01T00:00:00","2018-06-04T00:00:00","2018-06-05T00:00:00","2018-06-06T00:00:00","2018-06-07T00:00:00","2018-06-08T00:00:00","2018-06-11T00:00:00","2018-06-12T00:00:00","2018-06-13T00:00:00","2018-06-14T00:00:00","2018-06-15T00:00:00","2018-06-18T00:00:00","2018-06-19T00:00:00","2018-06-20T00:00:00","2018-06-21T00:00:00","2018-06-22T00:00:00","2018-06-25T00:00:00","2018-06-26T00:00:00","2018-06-27T00:00:00","2018-06-28T00:00:00","2018-06-29T00:00:00","2018-07-02T00:00:00","2018-07-03T00:00:00","2018-07-05T00:00:00","2018-07-06T00:00:00","2018-07-09T00:00:00","2018-07-10T00:00:00","2018-07-11T00:00:00","2018-07-12T00:00:00","2018-07-13T00:00:00","2018-07-16T00:00:00","2018-07-17T00:00:00","2018-07-18T00:00:00","2018-07-19T00:00:00","2018-07-20T00:00:00","2018-07-23T00:00:00","2018-07-24T00:00:00","2018-07-25T00:00:00","2018-07-26T00:00:00","2018-07-27T00:00:00","2018-07-30T00:00:00","2018-07-31T00:00:00","2018-08-01T00:00:00","2018-08-02T00:00:00","2018-08-03T00:00:00","2018-08-06T00:00:00","2018-08-07T00:00:00","2018-08-08T00:00:00","2018-08-09T00:00:00","2018-08-10T00:00:00","2018-08-13T00:00:00","2018-08-14T00:00:00","2 ...
# Epoch 1/25
# 45/45 [==============================] - 2s 7ms/step - loss: 61.9660 - val_loss: 0.6851
# Epoch 2/25
# 45/45 [==============================] - 0s 2ms/step - loss: 2.0099 - val_loss: 0.4247
# Epoch 3/25
# 45/45 [==============================] - 0s 3ms/step - loss: 1.3466 - val_loss: 0.5829
# Epoch 4/25
# 45/45 [==============================] - 0s 3ms/step - loss: 1.1623 - val_loss: 0.5666
# Epoch 5/25
# 45/45 [==============================] - 0s 5ms/step - loss: 0.8529 - val_loss: 0.4706
# Epoch 6/25
# 45/45 [==============================] - 0s 3ms/step - loss: 0.6811 - val_loss: 0.4579
# Epoch 7/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4917 - val_loss: 0.2645
# Epoch 8/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.2718 - val_loss: 0.2212
# Epoch 9/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1902 - val_loss: 0.2976
# Epoch 10/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1311 - val_loss: 0.2018
# Epoch 11/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0565 - val_loss: 0.1640
# Epoch 12/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0520 - val_loss: 0.1349
# Epoch 13/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0426 - val_loss: 0.0599
# Epoch 14/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0370 - val_loss: 0.0737
# Epoch 15/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0329 - val_loss: 0.0651
# Epoch 16/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0269 - val_loss: 0.0463
# Epoch 17/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0225 - val_loss: 0.0156
# Epoch 18/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0181 - val_loss: 0.0172
# Epoch 19/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0164 - val_loss: 0.0065
# Epoch 20/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0150 - val_loss: 0.0067
# Epoch 21/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0145 - val_loss: 0.0058
# Epoch 22/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0156 - val_loss: 0.0155
# Epoch 23/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0116 - val_loss: 0.0045
# Epoch 24/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0101 - val_loss: 0.0035
# Epoch 25/25
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0104 - val_loss: 0.0039
#                Close
# Date
# 2021-07-09  0.772122
# 2021-07-12  0.780935
# 2021-07-13  0.785181
# 2021-07-14  0.797636
# 2021-07-15  0.812203
# ...              ...
# 2022-05-16  0.780732
# 2022-05-17  0.771961
# 2022-05-18  0.828676
# 2022-05-19  0.734043
# 2022-05-20  0.718481
#
# [220 rows x 1 columns]
#
# Head of "inv_yhat":
#  [[148.63446171]
#  [149.92524785]
#  [150.54699613]
#  [152.37127182]
#  [154.50481973]]
#
# Head of "inv_testy":
#  [[145.11000061]
#  [144.5       ]
#  [145.63999939]
#  [149.1499939 ]
#  [148.47999573]]
# 1
# <div>                            <div id="9cf5ca57-70c6-4cbd-a373-aecd96407576" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9cf5ca57-70c6-4cbd-a373-aecd96407576")) {                    Plotly.newPlot(                        "9cf5ca57-70c6-4cbd-a373-aecd96407576",                        [{"mode":"lines","name":"Data","x":["2018-01-02T00:00:00","2018-01-03T00:00:00","2018-01-04T00:00:00","2018-01-05T00:00:00","2018-01-08T00:00:00","2018-01-09T00:00:00","2018-01-10T00:00:00","2018-01-11T00:00:00","2018-01-12T00:00:00","2018-01-16T00:00:00","2018-01-17T00:00:00","2018-01-18T00:00:00","2018-01-19T00:00:00","2018-01-22T00:00:00","2018-01-23T00:00:00","2018-01-24T00:00:00","2018-01-25T00:00:00","2018-01-26T00:00:00","2018-01-29T00:00:00","2018-01-30T00:00:00","2018-01-31T00:00:00","2018-02-01T00:00:00","2018-02-02T00:00:00","2018-02-05T00:00:00","2018-02-06T00:00:00","2018-02-07T00:00:00","2018-02-08T00:00:00","2018-02-09T00:00:00","2018-02-12T00:00:00","2018-02-13T00:00:00","2018-02-14T00:00:00","2018-02-15T00:00:00","2018-02-16T00:00:00","2018-02-20T00:00:00","2018-02-21T00:00:00","2018-02-22T00:00:00","2018-02-23T00:00:00","2018-02-26T00:00:00","2018-02-27T00:00:00","2018-02-28T00:00:00","2018-03-01T00:00:00","2018-03-02T00:00:00","2018-03-05T00:00:00","2018-03-06T00:00:00","2018-03-07T00:00:00","2018-03-08T00:00:00","2018-03-09T00:00:00","2018-03-12T00:00:00","2018-03-13T00:00:00","2018-03-14T00:00:00","2018-03-15T00:00:00","2018-03-16T00:00:00","2018-03-19T00:00:00","2018-03-20T00:00:00","2018-03-21T00:00:00","2018-03-22T00:00:00","2018-03-23T00:00:00","2018-03-26T00:00:00","2018-03-27T00:00:00","2018-03-28T00:00:00","2018-03-29T00:00:00","2018-04-02T00:00:00","2018-04-03T00:00:00","2018-04-04T00:00:00","2018-04-05T00:00:00","2018-04-06T00:00:00","2018-04-09T00:00:00","2018-04-10T00:00:00","2018-04-11T00:00:00","2018-04-12T00:00:00","2018-04-13T00:00:00","2018-04-16T00:00:00","2018-04-17T00:00:00","2018-04-18T00:00:00","2018-04-19T00:00:00","2018-04-20T00:00:00","2018-04-23T00:00:00","2018-04-24T00:00:00","2018-04-25T00:00:00","2018-04-26T00:00:00","2018-04-27T00:00:00","2018-04-30T00:00:00","2018-05-01T00:00:00","2018-05-02T00:00:00","2018-05-03T00:00:00","2018-05-04T00:00:00","2018-05-07T00:00:00","2018-05-08T00:00:00","2018-05-09T00:00:00","2018-05-10T00:00:00","2018-05-11T00:00:00","2018-05-14T00:00:00","2018-05-15T00:00:00","2018-05-16T00:00:00","2018-05-17T00:00:00","2018-05-18T00:00:00","2018-05-21T00:00:00","2018-05-22T00:00:00","2018-05-23T00:00:00","2018-05-24T00:00:00","2018-05-25T00:00:00","2018-05-29T00:00:00","2018-05-30T00:00:00","2018-05-31T00:00:00","2018-06-01T00:00:00","2018-06-04T00:00:00","2018-06-05T00:00:00","2018-06-06T00:00:00","2018-06-07T00:00:00","2018-06-08T00:00:00","2018-06-11T00:00:00","2018-06-12T00:00:00","2018-06-13T00:00:00","2018-06-14T00:00:00","2018-06-15T00:00:00","2018-06-18T00:00:00","2018-06-19T00:00:00","2018-06-20T00:00:00","2018-06-21T00:00:00","2018-06-22T00:00:00","2018-06-25T00:00:00","2018-06-26T00:00:00","2018-06-27T00:00:00","2018-06-28T00:00:00","2018-06-29T00:00:00","2018-07-02T00:00:00","2018-07-03T00:00:00","2018-07-05T00:00:00","2018-07-06T00:00:00","2018-07-09T00:00:00","2018-07-10T00:00:00","2018-07-11T00:00:00","2018-07-12T00:00:00","2018-07-13T00:00:00","2018-07-16T00:00:00","2018-07-17T00:00:00","2018-07-18T00:00:00","2018-07-19T00:00:00","2018-07-20T00:00:00","2018-07-23T00:00:00","2018-07-24T00:00:00","2018-07-25T00:00:00","2018-07-26T00:00:00","2018-07-27T00:00:00","2018-07-30T00:00:00","2018-07-31T00:00:00","2018-08-01T00:00:00","2018-08-02T00:00:00","2018-08-03T00:00:00","2018-08-06T00:00:00","2018-08-07T00:00:00","2018-08-08T00:00:00","2018-08-09T00:00:00","2018-08-10T00:00:00","2018-08-13T00:00:00","2018-08-14T00:00:00","2 ...
# Minimum of mae:  4.40017695071004
# Average of mae:  6.828506311376993
# Maximum of mae:  17.15645024837428
# [[132.77409691 115.15203195  99.53847733 116.36345507 150.95474973]
#  [131.34880132 122.53631969  92.70334486  62.22121876  44.92828205]
#  [130.6344643  112.40426088  68.61526273  56.92641723  68.4020821 ]
#  [137.07260271 125.04456127  90.06512898  52.45932066  15.91915579]
#  [133.62509092 118.17643435  91.15468347  74.20194881  72.12215929]
#  [130.62328137 116.74560403  71.95809495  43.12079549  35.41051843]
#  [130.23094468 113.99771075  71.8554407   58.43512867  69.59658241]
#  [129.49376165 114.18500084  70.85398999  25.41143154 -13.36454156]
#  [137.06393398 121.36584827  71.0346083   23.27216012  -6.52643221]
#  [140.77799412 131.11053766  86.00091039  48.2369653   37.33047377]]

# %%
# train = train_y.reshape(train_y.shape[0],1)
# train = np.hstack([train, np.zeros(train.shape)])
# train = scaler.inverse_transform(train)
# print(train)
# train = np.delete(train,[1,scaled_df.shape[1]],1)
# print(train)
# train = train.reshape((-1))
# test = inv_testy.reshape((-1))
# prediction = inv_yhat[:,:1]
# prediction = prediction.reshape((-1))
# print(train)

# %%
# score for forecast
actual_df =  DataReader(user_input, data_source='yahoo', start='2018-01-01', end=datetime.now())
actual_price = actual_df.filter(['Close'])
actual = actual_price[-5:]
print(actual)

seleted_forecast = forecast_5days[0]
print(seleted_forecast)
forecast_score = mean_absolute_error(seleted_forecast,actual)
print(forecast_score)
# Out:
#                  Close
# Date
# 2022-05-23  143.110001
# 2022-05-24  140.360001
# 2022-05-25  140.520004
# 2022-05-26  143.779999
# 2022-05-27  149.639999
# [132.77409691 115.15203195  99.53847733 116.36345507 150.95474973]
# 21.051338667867466

# %%
# arraya = np.array([[1,2,3,40,5,6,7],[2,3,4,5,6,7,8],[3,4,5,6,7,8,9]])
# var = np.var(arraya,axis=1)
# maxindex = np.argmax(var)
# new_arraya = np.delete(arraya,maxindex,0)
# print(new_arraya)
